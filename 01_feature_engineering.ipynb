# %%
import pandas as pd
import numpy as np
np.random.seed(0)
pd.set_option('display.max_columns', None)
from os.path import exists

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold

import mlflow
import missingno as msno
import gc

from sklearn.dummy import DummyRegressor
import xgboost as xgb
import catboost

import eli5
from tqdm import tqdm

# %%
def get_or_create_experiment(name):
    experiment = mlflow.get_experiment_by_name(name)
    if not experiment:
        mlflow.create_experiment(name)
        return mlflow.get_experiment_by_name(name)
        
    return experiment


def _eid(name):
    return get_or_create_experiment(name).experiment_id


def get_filename(basename):           
    counter=0
    name = '{}_{}'.format(basename, counter)
    while exists('../output/{}.csv'.format(name)):
        counter +=1
        name = '{}_{}'.format(basename, counter)
        
    return name

def get_X_y_log(df_train, feats):

    X = df_train[feats]
    y = df_train['price']
    y_log = np.log(y)
    
    return X, y, y_log
    

def get_feats(df):
    
    blacklist = [
        'price',
        'id', 
        'price_m2',  
       # 'tarasy',
       # 'ochrona',
       # 'created_at_cat',                          
       # 'garaż',       
       # 'plan zagospodarowania:',
       # 'area_num',
       # 'loc0_cat',        
        ]
    
                         
    num_bool_feats = df.select_dtypes(['number', 'bool'])
    return [x for x in num_bool_feats if x not in blacklist]


def get_model(model_or_id):
    
    if model_or_id == 'catboost_hyper':
        model_params = dict( 
            
            max_depth=8,
            n_estimators=1000,
            learning_rate=0.3,
            random_state=0,
            silent=True,
        )
        return catboost.CatBoostRegressor(**model_params)
    
    elif model_or_id == 'catboost_light':
        model_params = dict( 
            
            max_depth=5,
            n_estimators=100,
            random_state=0,
            silent=True,
        )
        return catboost.CatBoostRegressor(**model_params)
    else:
        return model_or_id


def mlflow_experiment(run_name, model, X, feats, result, eli5_result):
    
    with mlflow.start_run(experiment_id=_eid('dw_solution_property'), run_name=run_name) as run:
    
        mlflow.log_params(model.get_params())
        mlflow.log_param("model", str(model).split("(")[0])
        mlflow.log_param("feats", feats)
        mlflow.log_param('X.shape', X.shape)
        
        #artifacts
        with open('../outputs/eli5.html', 'w') as f:
            f.write('<html>{}</html>'.format(eli5_result.data))
        mlflow.log_artifact('../outputs/eli5.html', 'plot')
                
        #metrics
        mlflow.log_metric('mae_mean', result[0])
        mlflow.log_metric('mae_std', result[1])
              
    print(f'Experiment {run_name} recorded')

def check_model(X, y, model, scoring):
    
    cv = KFold(n_splits=5, shuffle=True, random_state=0)
    scores = []
    for train_idx, test_idx in tqdm(cv.split(X)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_log_train, y_test = np.log(y).iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_log_train)
        y_log_pred = model.predict(X_test)
        y_pred = np.exp(y_log_pred)

        score = scoring(y_test, y_pred)
        scores.append(score)
        
        return np.mean(scores), np.std(scores)
    
def save_forecast_to_csv(model, X_test, df_test, filename):

    y_pred = model.predict(X_test)
    df_test['price'] = np.exp(y_pred)
    
    try:
        df_test[ ['id', 'price'] ].to_csv('../output/{}.csv'.format(filename), index=False)
        print('{}.csv save successfully in "output" folder'.format(filename))
    except:
        print('{}.csv saving ERROR in "output" folder'.format(filename))
    
    
def start_experiment(df,
                     model_or_id,
                     scoring=mean_absolute_error,
                     filename='catboost',
                     results=True, export=False, mlflow_save=True):
    
    filename = get_filename(filename)    
    print(f'Working on "{filename}" experiment')
    
    #df
    df_train = df[ df['price'].notnull() ].fillna(-1)
    df_test = df[ df['price'].isnull() ].fillna(-1)
    
    #x Y
    feats = get_feats(df)
    X, y, y_log = get_X_y_log(df_train, feats)
    
    X = X
    y = y
 
    #model
    model = get_model(model_or_id)
    
    #results
    if results:
        result = check_model(X, y, model, scoring)
        
    model.fit(X.values, y_log.values)
    
    #export forecast
    if export:
        X_test = df_test[feats].values
        save_forecast_to_csv(model, X_test, df_test, filename)    
  
    eli5_result = eli5.show_weights(model, feature_names=feats)
    
    #mlflow
    if mlflow_save and result:
        mlflow_experiment(filename, model, X, feats, result, eli5_result)
    
    #return
    if results:
        print(result)
    return eli5_result

# %%
def feature_engineering(df):
    
    def parse_czynsz(val):
        if isinstance(val, int): return val
        if isinstance(val, float): return val

        if val[-1] == 'ł':
            return float(val.split('zł')[0].replace(' ', '').replace(',','.'))
        if val[-1] == 'r':
            return float(val.split('eur')[0].replace(' ', '').replace(',','.'))*4.5
    
    
    def parse_area(val):
        if isinstance(val, int): return val
        if isinstance(val, float): return val

        return float(val.split('m')[0].replace(',','.').replace(' ',''))
    

    def parse_location_city(val):
        all_city = city_stats['city'].to_list()
        for city in reversed(val):
            if city in ['Dobra', 'Józefów']:
                continue
            if city in all_city:
                return city
        return 'other'    
    

    def parse_floors_in_building(val):
        if isinstance(val, int): return -1
        if isinstance(val, float): return -1    
        floor = float(val.replace(')','').split()[1])
        return floor if floor < 20 else 25
    
    def df_groupby_feat(df, groupby_feats, feat):
        agg_params={
            'mean_{}_{}'.format('_'.join(groupby_feats), feat): (feat, 'mean'),
            'median_{}_{}'.format('_'.join(groupby_feats), feat): (feat, 'median'),
            #'sum_{}_price'.format('_'.join(groupby_feats)): ('price', 'sum')
        }
        return df[groupby_feats + [feat]].groupby(groupby_feats).agg(
            **agg_params
        ).reset_index()

    df['czynsz_num'] = df.czynsz.map(parse_czynsz)
    
    df['area_num'] = df.area.map(parse_area)
    area_num_99 = np.percentile(df['area_num'], 99)
    df['area_norm'] = df['area_num'].map(lambda x: x if x <= area_num_99 else area_num_99)
    df['area_num_log'] = np.log(df['area_num'])
    
    df['price_m2'] = df['price'] / df['area_num']
    
    df['province'] = df['location'].map(lambda x: x[0])
    df['city'] = df['location'].map(parse_location_city)
    df['floors_in_building_num'] = df['floors_in_building'].map(parse_floors_in_building)
    df['build_year'] = df['rok budowy'].fillna(-1).astype('int')
    
    floors_dict = {'parter': 0, '> 10': 11, 'poddasze': -2, 'suterena': -1}
    df['floor_num'] = df['floor'].map(lambda x: floors_dict.get(x, x)).fillna(-10).astype('int')
    
    
    if 'city_area' not in df.columns:
        df = pd.merge(df, city_stats, on='city', how='left')
    if 'province_population' not in df.columns:
        df = pd.merge(df, province_stats, on='province', how='left')
    
    miasta_woj = ['Białystok', 'Bydgoszcz', 'Gdańsk', 'Gorzów Wielkopolski', 'Katowice', 'Kielce', 'Kraków', 'Lublin',
    'Łódź', 'Olsztyn', 'Opole', 'Poznań', 'Rzeszów', 'Szczecin', 'Toruń', 'Warszawa', 'Wrocław', 'Zielona Góra']
    
    df['miasta_woj'] = df['city'].isin(miasta_woj)
    
    #Agregacje
    groupby_city_price = df_groupby_feat(df, ['city'], 'price')        
    if 'median_city_price' not in df:
        df = pd.merge(df, groupby_city_price, on='city', how='left')
        
    groupby_county_price = df_groupby_feat(df, ['county'], 'price')        
    if 'median_county_price' not in df:
        df = pd.merge(df, groupby_county_price, on='county', how='left')
    
    #groupby_city_pricem2 = df_groupby_feat(df, ['city'], 'price_m2')        
    #if 'median_county_price_m2' not in df:
    #    df = pd.merge(df, groupby_city_pricem2, on='city', how='left')
        
    #groupby_county_pricem2 = df_groupby_feat(df, ['county'], 'price_m2')        
    #if 'median_county_price_m2' not in df:
    #    df = pd.merge(df, groupby_county_pricem2, on='county', how='left')
        
    #groupby_province_price = df_group_price(df, ['province'])        
    #if 'median_province_price' not in df:
    #    df = pd.merge(df, groupby_province_price, on='province', how='left') 
    

    df['city_cat'] = df['city'].factorize()[0]
    df['county_cat'] = df['county'].factorize()[0]
    df['province_cat'] = df['province'].factorize()[0]
    
    
    cat_feats = {
        "materiał budynku": "build_material_cat",
        "okna": "window_cat",
        "stan wykończenia": "property_completion_cat",
        "rodzaj zabudowy": "property_type_cat",
        "ogrzewanie": "property_heating_cat",
        "forma własności": "own_property_cat"
     }    
    
    for feat_name, feat_new_name in cat_feats.items():
        df[feat_new_name] = df[feat_name].factorize()[0]
        
        #OHE
        df_dummies = pd.get_dummies(df[feat_name])
        df_dummies.columns = ['{0}_{1}'.format(feat_new_name, x) for x in df_dummies.columns]
        pd.concat([df, df_dummies], axis=1)
        
    stats = df['stats'].apply(pd.Series)
    df = pd.concat([df, stats], axis=1)
    dict_created_at={
        'ponad 14 dni temu':18,  
        '23.10.2018':17,
        '24.10.2018':16,
        '25.10.2018':15,
        '26.10.2018':14, 
        '27.10.2018':13,
        '28.10.2018':12,
        '29.10.2018':11,
        '30.10.2018':10,
        '31.10.2018':9,
        '01.11.2018':8,    
        '02.11.2018':7,
        '03.11.2018':6,
        '04.11.2018':5,
        '05.11.2018':4,
        '06.11.2018':3,
        '07.11.2018':2,
        '08.11.2018':1,
    }
        
    df['created_at_cat'] = df['created_at'].map(dict_created_at)
    #df['created_at_cat'] = df['created_at'].factorize()[0]
    #df['visit_ads_num'] = df.visit_ads.fillna(-1).astype('int')  
    df['visit_ads_num'] = df.visit_ads.map(lambda x: np.log(int(x) + 10) if not isinstance(x, float)  else -1)
    
    
    #Starter3
    #Location
    for i in range(5):
        df["loc{}".format(i)] = df["location"].map(lambda x: x[i] if len(x) > i else "")      
    
    df['loc01'] = df['loc0'] + df['loc1']
    df['loc012'] = df['loc0'] + df['loc1'] + df['loc2']
    df['loc12'] = df['loc1'] + df['loc2']
    
    #cat location
    for i in range(5):
        df["loc{}_cat".format(i)] = df["loc{}".format(i)].factorize()[0]
    df["loc01_cat"] = df['loc01'].factorize()[0]
    df["loc012_cat"] = df['loc012'].factorize()[0] 
    df["loc12_cat"] = df['loc12'].factorize()[0] 
    
    def groupby_location(df, loc, feat):
        groupby_feat = df_groupby_feat(df, [loc], feat)        
        if 'median_{}_price'.format(loc) not in df:
            return pd.merge(df, groupby_feat, on='{}'.format(loc), how='left')
    
    #df = groupby_location(df, 'loc01', 'price')    
    #df = groupby_location(df, 'loc12')
    
    #Starter 4
    
    df['security'] = df['system alarmowy'] | df['rolety antywłamaniowe'] | df['drzwi / okna antywłamaniowe']
    
    df['area_per_room'] = df['area_norm'] / df["rooms"]
    
    #start build year    
    years = [1970, 1980, 1990, 2000, 2005, 2010, 2012, 2014, 2016, 2017]
    #for idx in range(len(years) - 1):
    #    df["build_year_{0}-{1}".format(years[idx], years[idx+1])] = (df["build_year"] >= years[idx]) & (df["build_year"] < years[idx+1])
    
    #df["build_year_before_1970"] = df["build_year"] < 1970
    #df["build_year_after_2017"] = df["build_year"] > 2017

    def build_year_norm(year):
        if year < 1970: return 1900
        if year > 2017: return 2018

        for idx in range(len(years) - 1):
            if year >= years[idx] and year < years[idx+1]:
                return years[idx]

    df["build_year_norm"] = df["build_year"].map(build_year_norm)
    #end build year  
    
    big_cities = {'Poznań', 'Sopot', 'Wrocław', 'Kraków', 'Gdańsk', 'Gdynia', 'Opole', 'Katowice',  'Częstochowa', 'Szczecin', 'Kalisz', 'Łódź', 'Olsztyn', 'Warszawa'}
    for city in big_cities:
        df[city] = df['city'] == city
        df['big_city'] = df['city'].map(lambda x: x in big_cities)
        
    
    #location
    df_val_cnts = df['loc12'].value_counts()
    loc12_vals = set(df_val_cnts[ df_val_cnts > 100].index.values)
    for item in loc12_vals:
        df[item] = df['loc12'] == item
        
    
    #primary_market
    
    def is_primary_market_conc(df, feat):
        df['is_primary_market_{}'.format(feat)] = df[ ['is_primary_market', feat] ].apply(
            lambda x: '{}_{}'.format(x['is_primary_market'], x[feat]), axis=1
        )
        df['is_primary_market_{}_cat'.format(feat)] = df['is_primary_market_{}'.format(feat)].factorize()[0]

        return df
    
    df = is_primary_market_conc(df, 'rooms')
    df = is_primary_market_conc(df, 'city')
    df = is_primary_market_conc(df, 'rodzaj zabudowy') 
    
    #agregacje price_m2
    groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_rooms'], 'price_m2')
    df = pd.merge(df, groupby_price_m2, on='is_primary_market_rooms', how='left')
    
    #groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_city'], 'price_m2')
    #df = pd.merge(df, groupby_price_m2, on='is_primary_market_city', how='left')
    
    groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_rodzaj zabudowy'], 'price_m2')
    df = pd.merge(df, groupby_price_m2, on='is_primary_market_rodzaj zabudowy', how='left')
    

                                                                   
    return df

# %%
ls ../input_ext/
# Out:
# city_stats.csv  region_stats.csv

# %%
ls ../input/
# Out:
# big_train_warsaw_property.h5  train_data.h5@
# test_warsaw_property.h5       train_warsaw_property.h5

# %%
df_train = pd.read_hdf('../input/train_warsaw_property.h5')
df_test = pd.read_hdf('../input/test_warsaw_property.h5')

#big data set
df_train = pd.read_hdf('../input/big_train_warsaw_property.h5')

df_org = pd.concat([df_train, df_test])

#External city and region data (Wikipedia)
city_stats = pd.read_csv('../input_ext/city_stats.csv')
city_stats.drop('Województwo', axis=1, inplace=True)
city_stats.columns = ['city', 'county', 'city_area', 'city_population', 'city_density']

province_stats = pd.read_csv('../input_ext/province_stats.csv')
province_stats.drop('Lp.', axis=1, inplace=True)
province_stats.columns = ['province', 'province_population', 'province_men_population', 'province_women_population']

df_train.shape, df_test.shape, df_org.shape
# Out:
# ((46489, 53), (46275, 52), (92764, 53))

# %%
df = feature_engineering(df_org.copy())
print(df.shape)
df.sample(3)
# Out:
# (92764, 343)
#           id                                           location  is_private  \
# 74040  55250                       [śląskie, Bytom, Miechowice]           0
# 83926  75161                        [śląskie, Gliwice, Żerniki]           0
# 68156  43530  [małopolskie, Kraków, Stare Miasto, ul. Krowod...           0
#
#        piekarnik  garaż  monitoring / ochrona  rolety antywłamaniowe  \
# 74040      False  False                 False                  False
# 83926      False  False                 False                  False
# 68156      False  False                 False                  False
#
#        kuchenka  taras  balkon  ogródek  dwupoziomowe  system alarmowy  \
# 74040     False  False    True    False         False            False
# 83926     False  False   False    False         False            False
# 68156     False  False   False    False         False            False
#
#        pom. użytkowe  klimatyzacja  tarasy  teren zamknięty  internet  winda  \
# 74040          False         False   False            False     False  False
# 83926          False         False   False            False     False  False
# 68156          False         False   False            False     False   True
#
#        telefon  pralka  piwnica  ochrona  telewizja kablowa  telewizor  \
# 74040    False   False    False    False              False      False
# 83926    False   False     True    False              False      False
# 68156    False    True    False    False              False      False
#
#        lodówka  domofon / wideofon  oddzielna kuchnia  zmywarka  \
# 74040    False               False              False     False
# 83926    False               False              False     False
# 68156     True                True              False     False
#
#        garaż/miejsce parkingowe  meble  drzwi / okna antywłamaniowe  \
# 74040                     False  False                        False
# 83926                     False  False                        False
# 68156                     False   True                        False
#
#        plan zagospodarowania:  price      area  rooms   floor  \
# 74040                   False    NaN     60 m²      3       4
# 83926                   False    NaN  51,43 m²      2  parter
# 68156                   False    NaN  67,30 m²      2       1
#
#       floors_in_building dostępne od rok budowy materiał budynku        okna  \
# 74040              (z 4)         NaN        NaN             inne         NaN
# 83926              (z 2)         NaN        NaN              NaN  plastikowe
# 68156              (z 4)         NaN       1900            cegła  plastikowe
#
#       data rozpoczęcia stan inwestycji liczba kondygnacji stan wykończenia  \
# 74040              NaN             NaN                NaN  do zamieszkania
# 83926              NaN             NaN                NaN              NaN
# 68156              NaN             NaN                NaN  do zamieszkania
#
#        czynsz rodzaj zabudowy ogrzewanie        forma własności  \
# 74040     NaN            blok   miejskie  spółdzielcze wł. z kw
# 83926  530 zł             NaN        NaN                    NaN
# 68156  300 zł       kamienica   miejskie         pełna własność
#
#                                                    stats  \
# 74040  {'ID': 113014296, 'visit_ads': '55', 'created_...
# 83926  {'ID': 111452864, 'visit_ads': '175', 'created...
# 68156  {'ID': 108889064, 'created_at': 'ponad 14 dni ...
#
#                                                     text  is_primary_market  \
# 74040  Opis Oferujemy do sprzedaży przestronne trzypo...              False
# 83926  Opis Na sprzedaż wyremontowane i umeblowane mi...              False
# 68156  Opis Biuro Nieruchomości Stare Miasto prezentu...              False
#
#        czynsz_num  area_num  area_norm  area_num_log  price_m2     province  \
# 74040         NaN     60.00      60.00      4.094345       NaN      śląskie
# 83926       530.0     51.43      51.43      3.940222       NaN      śląskie
# 68156       300.0     67.30      67.30      4.209160       NaN  małopolskie
#
#           city  floors_in_building_num  build_year  floor_num      county  \
# 74040    Bytom                     4.0          -1          4    Bytom[a]
# 83926  Gliwice                     2.0          -1          0  Gliwice[a]
# 68156   Kraków                     4.0        1900          1   Kraków[a]
#
#        city_area  city_population  city_density  province_population  \
# 74040      69.44         168394.0        2425.0              4570849
# 83926     133.88         181309.0        1354.0              4570849
# 68156     326.85         767348.0        2348.0              3372618
#
#        province_men_population  province_women_population  miasta_woj  \
# 74040                  2204972                    2365877       False
# 83926                  2204972                    2365877       False
# 68156                  1636707                    1735911        True
#
#        mean_city_price  median_city_price  mean_county_price  \
# 74040      148897.3125           145000.0        148897.3125
# 83926      266079.6250           237380.0        266079.6250
# 68156      529502.5000           416305.0        529502.5000
#
#        median_county_price  city_cat  county_cat  province_cat  \
# 74040             145000.0       371         222            11
# 83926             237380.0       365         217            11
# 68156             416305.0       162         100             5
#
#        build_material_cat  window_cat  property_completion_cat  \
# 74040                   4          -1                        1
# 83926                  -1           0                       -1
# 68156                   1           0                        1
#
#        property_type_cat  property_heating_cat  own_property_cat         ID  \
# 74040                  1                     1                 1  113014296
# 83926                 -1                    -1                -1  111452864
# 68156                  2                     1                 0  108889064
#
#               created_at         updated_at visit_ads  created_at_cat  \
# 74040         07.11.2018         07.11.2018        55               2
# 83926  ponad 14 dni temu  ponad 14 dni temu       175              18
# 68156  ponad 14 dni temu         04.11.2018       NaN              18
#
#        visit_ads_num         loc0     loc1          loc2             loc3  \
# 74040       4.174387      śląskie    Bytom    Miechowice
# 83926       5.220356      śląskie  Gliwice       Żerniki
# 68156      -1.000000  małopolskie   Kraków  Stare Miasto  ul. Krowoderska
#
#       loc4              loc01                         loc012  \
# 74040            śląskieBytom         śląskieBytomMiechowice
# 83926          śląskieGliwice          śląskieGliwiceŻerniki
# 68156       małopolskieKraków  małopolskieKrakówStare Miasto
#
#                     loc12  loc0_cat  loc1_cat  loc2_cat  loc3_cat  loc4_cat  \
# 74040     BytomMiechowice        11       217      2289         1         0
# 83926      GliwiceŻerniki        11       212       173         1         0
# 68156  KrakówStare Miasto         5        95        26      2623         0
#
#        loc01_cat  loc012_cat  loc12_cat  security  area_per_room  \
# 74040        223        2548       2548     False         20.000
# 83926        218        3343       3343     False         25.715
# 68156         97         933        933     False         33.650
#
#        build_year_norm  Sopot  big_city  Wrocław  Poznań  Częstochowa  Gdańsk  \
# 74040           1900.0  False     False    False   False        False   False
# 83926           1900.0  False     False    False   False        False   False
# 68156           1900.0  False      True    False   False        False   False
#
#        Kalisz  Opole  Olsztyn  Gdynia  Katowice  Warszawa   Łódź  Kraków  \
# 74040   False  False    False   False     False     False  False   False
# 83926   False  False    False   False     False     False  False   False
# 68156   False  False    False   False     False     False  False    True
#
#        Szczecin  tarnogórskiTarnowskie Góry  SzczecinWarszewo  \
# 74040     False                       False             False
# 83926     False                       False             False
# 68156     False                       False             False
#
#        KatowiceŚródmieście  Zielona GóraCentrum  WrocławZłotniki  \
# 74040                False                False            False
# 83926                False                False            False
# 68156                False                False            False
#
#        KrakówWola Justowska  wejherowskiRumia  BiałystokAntoniuk  \
# 74040                 False             False              False
# 83926                 False             False              False
# 68156                 False             False              False
#
#        GdańskJelitkowo  KatowiceJózefowiec  KatowiceKostuchna  \
# 74040            False               False              False
# 83926            False               False              False
# 68156            False               False              False
#
#        stargardzkiStargard  BiałystokCentrum  GdańskŁostowice  PoznańJeżyce  \
# 74040                False             False            False         False
# 83926                False             False            False         False
# 68156                False             False            False         False
#
#        ŁódźWidzew  GdyniaRedłowo  BiałystokWysoki Stoczek  WarszawaBielany  \
# 74040       False          False                    False            False
# 83926       False          False                    False            False
# 68156       False          False                    False            False
#
#        KrakówWzgórza Krzesławickie  WarszawaUrsus  WrocławŚródmieście  \
# 74040                        False          False               False
# 83926                        False          False               False
# 68156                        False          False               False
#
#        TychyŻwaków  świdnickiŚwidnica  WarszawaŻoliborz  SopotDolny  \
# 74040        False              False             False       False
# 83926        False              False             False       False
# 68156        False              False             False       False
#
#        LublinWęglinek  poznańskiLuboń  KrakówDębniki  BydgoszczGlinki  \
# 74040           False           False          False            False
# 83926           False           False          False            False
# 68156           False           False          False            False
#
#        WarszawaŚródmieście  OpoleŚródmieście  KrakówMistrzejowice  \
# 74040                False             False                False
# 83926                False             False                False
# 68156                False             False                False
#
#        namysłowskiNamysłów  PoznańPiątkowo  WrocławPsie Pole  \
# 74040                False           False             False
# 83926                False           False             False
# 68156                False           False             False
#
#        SzczecinGumieńce  WarszawaTargówek  GdańskUjeścisko  \
# 74040             False             False            False
# 83926             False             False            False
# 68156             False             False            False
#
#        BydgoszczOsiedle Leśne  GdańskŚródmieście  BydgoszczFordon  ŁódźGórna  \
# 74040                   False              False            False      False
# 83926                   False              False            False      False
# 68156                   False              False            False      False
#
#        GdańskKowale  WrocławStare Miasto  GdańskOliwa  GliwiceCentrum  \
# 74040         False                False        False           False
# 83926         False                False        False           False
# 68156         False                False        False           False
#
#        poznańskiZalasewo  ostrowskiOstrów Wielkopolski  BydgoszczBielawy  \
# 74040              False                         False             False
# 83926              False                         False             False
# 68156              False                         False             False
#
#        ToruńJakubskie Przedmieście  GdańskPrzymorze  KrakówKurdwanów  \
# 74040                        False            False            False
# 83926                        False            False            False
# 68156                        False            False            False
#
#        WarszawaUrsynów  ToruńKoniuchy  wejherowskiWejherowo  \
# 74040            False          False                 False
# 83926            False          False                 False
# 68156            False          False                 False
#
#        Dąbrowa GórniczaGołonóg  Zielona Góra  poznańskiSwarzędz  Gliwice  \
# 74040                    False         False              False    False
# 83926                    False         False              False    False
# 68156                    False         False              False    False
#
#        PoznańWilczak  LublinLSM  KatowicePiotrowice  SosnowiecPogoń  \
# 74040          False      False               False           False
# 83926          False      False               False           False
# 68156          False      False               False           False
#
#        WarszawaWola  LublinCentrum  GdyniaObłuże  będzińskiBędzin  \
# 74040         False          False         False            False
# 83926         False          False         False            False
# 68156         False          False         False            False
#
#        KrakówBronowice Małe  SosnowiecCentrum  ŁódźPolesie  \
# 74040                 False             False        False
# 83926                 False             False        False
# 68156                 False             False        False
#
#        PoznańStare Miasto  WarszawaBiałołęka  SosnowiecZagórze  LublinCzuby  \
# 74040               False              False             False        False
# 83926               False              False             False        False
# 68156               False              False             False        False
#
#        WarszawaMokotów  CzęstochowaParkitka  KrakówPodgórze  krakowskiSkawina  \
# 74040            False                False           False             False
# 83926            False                False           False             False
# 68156            False                False           False             False
#
#        WrocławMaślice  LublinSzerokie  SzczecinNiebuszewo  WrocławKlecina  \
# 74040           False           False               False           False
# 83926           False           False               False           False
# 68156           False           False               False           False
#
#        wrocławskiKiełczów  ełckiEłk  LublinWrotków  BydgoszczGórzyskowo  \
# 74040               False     False          False                False
# 83926               False     False          False                False
# 68156               False     False          False                False
#
#        PoznańWilda  GdańskMorena  głogowskiGłogów  KrakówBieżanów-Prokocim  \
# 74040        False         False            False                    False
# 83926        False         False            False                    False
# 68156        False         False            False                    False
#
#        KrakówBronowice  RzeszówSłocina  piaseczyńskiPiaseczno  GdyniaOksywie  \
# 74040            False           False                  False          False
# 83926            False           False                  False          False
# 68156            False           False                  False          False
#
#        KielceCentrum  PoznańRataje  WrocławStabłowice  WrocławGaj  \
# 74040          False         False              False       False
# 83926          False         False              False       False
# 68156          False         False              False       False
#
#        KatowiceOsiedle Paderewskiego  tczewskiTczew  wrocławskiSiechnice  \
# 74040                          False          False                False
# 83926                          False          False                False
# 68156                          False          False                False
#
#        ToruńNa Skarpie  WrocławPlac Grunwaldzki  BydgoszczBłonie  \
# 74040            False                    False            False
# 83926            False                    False            False
# 68156            False                    False            False
#
#        KrakówRuczaj  piaseczyńskiJózefosław  WarszawaPraga-Północ  \
# 74040         False                   False                 False
# 83926         False                   False                 False
# 68156         False                   False                 False
#
#        gdańskiPruszcz Gdański  Wrocławul. Brzoskwiniowa  SzczecinCentrum  \
# 74040                   False                     False            False
# 83926                   False                     False            False
# 68156                   False                     False            False
#
#        ŁódźBałuty  PoznańWinogrady  GdyniaOrłowo  PoznańGrunwald  \
# 74040       False            False         False           False
# 83926       False            False         False           False
# 68156       False            False         False           False
#
#        lęborskiLębork  GdyniaWitomino  WarszawaBemowo  WarszawaOchota  \
# 74040           False           False           False           False
# 83926           False           False           False           False
# 68156           False           False           False           False
#
#        PoznańBułgarska 59  WarszawaSaska Kępa  pruszkowskiPruszków  \
# 74040               False               False                False
# 83926               False               False                False
# 68156               False               False                False
#
#        ToruńMokre  BydgoszczCentrum  KrakówSalwator  WarszawaGocław  \
# 74040       False             False           False           False
# 83926       False             False           False           False
# 68156       False             False           False           False
#
#        BydgoszczKapuściska  KrakówPrądnik Czerwony  SzczecinŚródmieście  \
# 74040                False                   False                False
# 83926                False                   False                False
# 68156                False                   False                False
#
#        KatowiceBrynów  KrakówKrowodrza  KrakówNowa Huta  PoznańGórczyn  \
# 74040           False            False            False          False
# 83926           False            False            False          False
# 68156           False            False            False          False
#
#        ŁódźŚródmieście  WrocławTarnogaj  BiałystokBojary  KrakówŚródmieście  \
# 74040            False            False            False              False
# 83926            False            False            False              False
# 68156            False            False            False              False
#
#        GdańskJasień  KatowiceOsiedle Tysiąclecia  dzierżoniowskiDzierżoniów  \
# 74040         False                        False                      False
# 83926         False                        False                      False
# 68156         False                        False                      False
#
#        kamieńskiMiędzyzdroje  WrocławSwojczyce  BiałystokNowe Miasto  \
# 74040                  False             False                 False
# 83926                  False             False                 False
# 68156                  False             False                 False
#
#        ToruńChełmińskie Przedmieście  Grudziądz  puckiJastarnia  \
# 74040                          False      False           False
# 83926                          False      False           False
# 68156                          False      False           False
#
#        inowrocławskiInowrocław  lubińskiLubin  PoznańNowe Miasto  \
# 74040                    False          False              False
# 83926                    False          False              False
# 68156                    False          False              False
#
#        wejherowskiReda  KrakówGrzegórzki  KrakówStare Podgórze  BytomCentrum  \
# 74040            False             False                 False         False
# 83926            False             False                 False         False
# 68156            False             False                 False         False
#
#        BydgoszczWyżyny  tatrzańskiZakopane  wołomińskiMarki  Kielce  \
# 74040            False               False            False   False
# 83926            False               False            False   False
# 68156            False               False            False   False
#
#        będzińskiSiewierz  KrakówCzyżyny  WarszawaWawer  GdańskWrzeszcz  \
# 74040              False          False          False           False
# 83926              False          False          False           False
# 68156              False          False          False           False
#
#        SzczecinPogodno  Gorzów WielkopolskiGórczyn  ToruńRubinkowo  \
# 74040            False                       False           False
# 83926            False                       False           False
# 68156            False                       False           False
#
#        ToruńBydgoskie Przedmieście  PoznańPodolany  WrocławMuchobór Wielki  \
# 74040                        False           False                   False
# 83926                        False           False                   False
# 68156                        False           False                   False
#
#        WrocławJagodno  KrakówŁobzów  KatowiceDolina Trzech Stawów  \
# 74040           False         False                         False
# 83926           False         False                         False
# 68156           False         False                         False
#
#        GdyniaŚródmieście  wołomińskiZąbki  WarszawaWłochy  \
# 74040              False            False           False
# 83926              False            False           False
# 68156              False            False           False
#
#        BydgoszczŚródmieście  PoznańCentrum  LublinFelin  GliwiceStare Gliwice  \
# 74040                 False          False        False                 False
# 83926                 False          False        False                 False
# 68156                 False          False        False                 False
#
#        CzęstochowaTysiąclecie  KielceŚlichowice  WrocławHuby  \
# 74040                   False             False        False
# 83926                   False             False        False
# 68156                   False             False        False
#
#        PoznańNaramowice  GdańskChełm  BydgoszczSzwederowo  WrocławKrzyki  \
# 74040             False        False                False          False
# 83926             False        False                False          False
# 68156             False        False                False          False
#
#        WarszawaPowiśle  KrakówStare Miasto  GdańskSiedlce  Rzeszów  \
# 74040            False               False          False    False
# 83926            False               False          False    False
# 68156            False                True          False    False
#
#        KrakówKazimierz  LublinDziesiąta  wielickiWieliczka  \
# 74040            False            False              False
# 83926            False            False              False
# 68156            False            False              False
#
#        BydgoszczBartodzieje  KrakówKliny-Zacisze  GdańskStare Miasto  \
# 74040                 False                False               False
# 83926                 False                False               False
# 68156                 False                False               False
#
#        WrocławFabryczna  PoznańŁazarz  KrakówOlsza  RzeszówDrabinianka  \
# 74040             False         False        False               False
# 83926             False         False        False               False
# 68156             False         False        False               False
#
#        kołobrzeskiKołobrzeg  WarszawaWilanów  SopotGórny  GdańskZaspa  \
# 74040                 False            False       False        False
# 83926                 False            False       False        False
# 68156                 False            False       False        False
#
#        WarszawaPraga-Południe  KrakówPrądnik Biały  GdyniaMały Kack  \
# 74040                   False                False            False
# 83926                   False                False            False
# 68156                   False                False            False
#
#        KrakówWola Duchacka  KatowiceWełnowiec  ZabrzeCentrum  \
# 74040                False              False          False
# 83926                False              False          False
# 68156                False              False          False
#
#        LublinŚródmieście is_primary_market_rooms  is_primary_market_rooms_cat  \
# 74040              False                 False_3                            4
# 83926              False                 False_2                            3
# 68156              False                 False_2                            3
#
#       is_primary_market_city  is_primary_market_city_cat  \
# 74040            False_Bytom                         543
# 83926          False_Gliwice                         530
# 68156           False_Kraków                         222
#
#       is_primary_market_rodzaj zabudowy  \
# 74040                        False_blok
# 83926                         False_nan
# 68156                   False_kamienica
#
#        is_primary_market_rodzaj zabudowy_cat  \
# 74040                                      3
# 83926                                      2
# 68156                                      5
#
#        mean_is_primary_market_rooms_price_m2  \
# 74040                            6013.719309
# 83926                            6437.640518
# 68156                            6437.640518
#
#        median_is_primary_market_rooms_price_m2  \
# 74040                              5395.683453
# 83926                              5813.953488
# 68156                              5813.953488
#
#        mean_is_primary_market_rodzaj zabudowy_price_m2  \
# 74040                                      5587.835882
# 83926                                      6265.400057
# 68156                                      6034.568709
#
#        median_is_primary_market_rodzaj zabudowy_price_m2
# 74040                                        5201.773009
# 83926                                        5605.633803
# 68156                                        4906.693992

# %% [markdown]
# # BASIC MODEL - Kaggle Score: 182576.93612

# %%
feats = ['id']
model = DummyRegressor()
model.fit(df_train[feats].values, df_train['price'])
y_pred = model.predict(df_test[feats].values)

df_test['price'] = y_pred
df_test[ ['id', 'price'] ].to_csv('../output/DummyRegressor.csv', index=False)

# %%
#msno.bar(df_train.iloc[:,40:50])

# %% [markdown]
# # ⭐ DAY 4 MODEL = Score: 51517.18706 Public score: 54286.18086

# %% [markdown]
# ## 🤖 MLflow

# %%
# !mlflow ui --backend-store-uri file:///home/jovyan/dwsolutions/property_warsaw/notebooks/mlruns
# Out:
# [2022-06-19 19:10:06 +0000] [193] [INFO] Starting gunicorn 20.1.0
# [2022-06-19 19:10:06 +0000] [193] [INFO] Listening at: http://127.0.0.1:5000 (193)
# [2022-06-19 19:10:06 +0000] [193] [INFO] Using worker: sync
# [2022-06-19 19:10:06 +0000] [195] [INFO] Booting worker with pid: 195
# ^C
# [2022-06-19 19:13:52 +0000] [193] [INFO] Handling signal: int
# [2022-06-19 19:13:53 +0000] [195] [INFO] Worker exiting (pid: 195)

# %% [markdown]
#  ### [Dashboard](/hub/user-redirect/proxy/5000/)

# %%
start_experiment(df, 'catboost_hyper', scoring=mean_absolute_error, filename='catboost', results=True, export=False, mlflow_save=False)
# Out:
# Working on "catboost_0" experiment
# 0it [00:30, ?it/s]
# (50700.473806202695, 0.0)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1042
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num_log
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0839
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0556
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0527
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0480
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_is_primary_market_rodzaj zabudowy_price_m2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0427
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0366
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0300
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0277
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 visit_ads_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0240
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_area
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0229
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0180
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_completion_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0174
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_per_room
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0174
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 loc2_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.43%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0168
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0167
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_heating_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0163
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_density
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0162
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors_in_building_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0123
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
start_experiment(df,
                 'catboost_hyper',
                 scoring=mean_absolute_error,
                 filename='catboost',
                 results=False,
                 export=True,
                 mlflow_save=False)
# Out:
# Working on "catboost_5" experiment
# catboost_5.csv save successfully in "output" folder
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1058
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num_log
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0843
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0540
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0532
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0511
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_is_primary_market_rodzaj zabudowy_price_m2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0429
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0359
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0306
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0275
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 visit_ads_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0237
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_area
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0232
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0172
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors_in_building_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0169
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_completion_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_heating_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_per_room
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0164
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_density
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0155
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 loc2_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0130
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
start_experiment(df,
                 'catboost_hyper',
                 scoring=mean_absolute_error,
                 filename='catboost',
                 results=True,
                 export=False,
                 mlflow_save=True)
# Out:
# Working on "catboost_3" experiment
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-7febb5c937b5> in <module>
# ----> 1 start_experiment(df,
#       2                  'catboost_hyper',
#       3                  scoring=mean_absolute_error,
#       4                  filename='catboost',
#       5                  results=True,
#
# <ipython-input-50-8ca56f8692c4> in start_experiment(df, model_or_id, scoring, filename, results, export, mlflow_save)
#     155     #results
#     156     if results:
# --> 157         result = check_model(X, y, model, scoring)
#     158
#     159     model.fit(X.values, y_log.values)
#
# <ipython-input-50-8ca56f8692c4> in check_model(X, y, model, scoring)
#     106     scores = []
#     107     for train_idx, test_idx in tqdm(cv.split(X)):
# --> 108         X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
#     109         y_log_train, y_test = np.log(y).iloc[train_idx], y.iloc[test_idx]
#     110
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
df['winda_test'] = df["text"].map(lambda x: True if ('winda' in x) | ('windą' in x) | ('windy' in x) | ('windę' in x) else False)
df['winda_test']
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 92759    False
# 92760    False
# 92761     True
# 92762    False
# 92763     True
# Name: winda_test, Length: 92764, dtype: bool

# %%
df['winda_ext'] = df.apply(lambda x: True if (x['winda']) | (x['winda_test']) else False, axis=1)
