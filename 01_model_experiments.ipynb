# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold
from sklearn.dummy import DummyRegressor

import eli5
import catboost

import mlflow
import missingno as msno
import gc
from os.path import exists
from tqdm import tqdm

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Defining function used for experiments

# %%
def get_or_create_experiment(experiment_name):
    """Checks if mlflow experiment already exist (if not creates it) and return it."""
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if not experiment:
        mlflow.create_experiment(name)
        return mlflow.get_experiment_by_name(experiment_name)        
    return experiment


def _eid(experiment_name):
    return get_or_create_experiment(experiment_name).experiment_id


def get_filename(basename):
    """Creates unique filename to prevent overwriting files in target directory when exporting the forecast."""
    counter=0
    name = '{}_{}'.format(basename, counter)  # filename in format <basename>_<number>.csv
    # Adds +1 to <number> until it gets unique filename
    while exists('../output/{}.csv'.format(name)):
        counter +=1
        filename = '{}_{}'.format(basename, counter)        
    return filename


def get_X_y_log(df, feats):
    """Creates feature matrix, target and logarihtmic vector for model training."""
    X = df[feats]
    y = df['price']
    y_log = np.log(y)    
    return X, y, y_log
    

def get_feats(df, blacklist_extended):
    """Creates training features by taking all number and boolean columns 
    from provided dataframe, reduced by those in blacklist.
    """    
    blacklist = [
        'price',
        'id', 
        'price_m2',
    ]
    # Extra blacklist feature can be added as list in function argument. 
    if blacklist_extended:
        blacklist = blacklist + blacklist_extended       
                         
    num_bool_feats = df.select_dtypes(['number', 'bool'])
    return [x for x in num_bool_feats if x not in blacklist]


def get_model(model_or_id):
    """Returns one of two default models, or alternative one, provided as function argument."""
    if model_or_id == 'catboost_hyper':  # hyper parameters tuned for better forecast, but longer model training.
        model_params = dict(             
            max_depth=8,
            n_estimators=1000,
            learning_rate=0.3,
            random_state=0,
            silent=True,
        )
        return catboost.CatBoostRegressor(**model_params)
    
    elif model_or_id == 'catboost_light':  # hyper parameters tuned for quick results.
        model_params = dict(            
            max_depth=5,
            n_estimators=100,
            random_state=0,
            silent=True,
        )
        return catboost.CatBoostRegressor(**model_params)
    else:
        return model_or_id


def mlflow_experiment(run_name, model, X, feats, result, eli5_result):
    """Uses MLflow tool to record and track important information about experiments.
    Such as model parameters, shape of feature and targe matrix, feats used for model training or eli5 importance of the features
    """
    with mlflow.start_run(experiment_id=_eid('dw_solution_property'), run_name=run_name) as run:
    
        mlflow.log_params(model.get_params())
        mlflow.log_param("model", str(model).split("(")[0])
        mlflow.log_param("feats", feats)
        mlflow.log_param('X.shape', X.shape)
        
        # artifacts
        with open('../outputs/eli5.html', 'w') as f:
            f.write('<html>{}</html>'.format(eli5_result.data))
        mlflow.log_artifact('../outputs/eli5.html', 'plot')
                
        # metrics
        mlflow.log_metric('mae_mean', result[0])
        mlflow.log_metric('mae_std', result[1])
              
    print(f'Experiment {run_name} recorded')

    
def check_model(X, y, model, scoring):
    """Evaluate model based on selected metric."""
    cv = KFold(n_splits=5, shuffle=True, random_state=0)
    scores = []
    for train_idx, test_idx in tqdm(cv.split(X)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_log_train, y_test = np.log(y).iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_log_train)
        y_log_pred = model.predict(X_test)
        y_pred = np.exp(y_log_pred)

        score = scoring(y_test, y_pred)
        scores.append(score)
        
        return np.mean(scores), np.std(scores)
    
    
def save_forecast_to_csv(model, X_test, df_test, filename):
    """Exports forecast to csv file"""
    y_pred = model.predict(X_test)
    df_test['price'] = np.exp(y_pred)
    
    try:
        df_test[ ['id', 'price'] ].to_csv('../output/{}.csv'.format(filename), index=False)
        print('{}.csv save successfully in "output" folder'.format(filename))
    except:
        print('{}.csv saving ERROR in "output" folder'.format(filename))
    
    
def start_experiment(df, model_or_id, scoring=mean_absolute_error,
                     filename='catboost',
                     results=True, export=False, mlflow_save=True, blacklist_extended=None):
    """Main function to conducts experiment.
    
    Main feature are:
    record experiment data using MLflow - "mlflow_save" argument,
    showing results based on selected metric - "results" argument,
    exporting forecast to csv file - "export" argument.
    All above argument are boolean and can be set independently according to expected output.
    Mlflow_save argument can be set to True only if results argument is also set to True.
    """
    if mlflow_save:
        assert results, '"mlflow_save" argument can be set to True only if "results" argument is also set to True'
        
    filename = get_filename(filename)    
    print(f'Working on "{filename}" experiment')
    
    # Splits dataset into train and test dataframes.     
    df_train = df[ df['price'].notnull() ].fillna(-1)  # takes all rows with "price" column NOT empty
    df_test = df[ df['price'].isnull() ].fillna(-1)  # # takes all rows with "price" column empty
    
    # Gets X and y (feature matrix and target vector). 
    feats = get_feats(df, blacklist_extended )
    X, y, y_log = get_X_y_log(df_train, feats)

    # Gets model
    model = get_model(model_or_id)
    
    # Returning results
    if results:
        result = check_model(X, y, model, scoring)
        
    model.fit(X.values, y_log.values)
    
    # Export forecast to csv.
    if export:
        X_test = df_test[feats].values
        save_forecast_to_csv(model, X_test, df_test, filename)    
  
    eli5_result = eli5.show_weights(model, feature_names=feats)
    
    #MLflow tracking
    if mlflow_save and results:
        mlflow_experiment(filename, model, X, feats, result, eli5_result)

    if results:
        print(result)
    return eli5_result

# %% [markdown]
# ## Feature engineering

# %%
def feature_engineering(df):
    
    def parse_czynsz(val):
        if isinstance(val, int): return val
        if isinstance(val, float): return val

        if val[-1] == 'ł':
            return float(val.split('zł')[0].replace(' ', '').replace(',','.'))
        if val[-1] == 'r':
            return float(val.split('eur')[0].replace(' ', '').replace(',','.'))*4.5
    
    
    def parse_area(val):
        if isinstance(val, int): return val
        if isinstance(val, float): return val

        return float(val.split('m')[0].replace(',','.').replace(' ',''))
    

    def parse_location_city(val):
        all_city = city_stats['city'].to_list()
        for city_ in reversed(val):
            if city_ in ['Dobra', 'Józefów']:
                continue
            if city_ in all_city:
                return city_
        return 'other'    
    

    def parse_floors_in_building(val):
        if isinstance(val, int): return -1
        if isinstance(val, float): return -1    
        floor = float(val.replace(')','').split()[1])
        return floor if floor < 20 else 25
    
    def df_groupby_feat(df, groupby_feats, feat):
        agg_params={
            'mean_{}_{}'.format('_'.join(groupby_feats), feat): (feat, 'mean'),
            'median_{}_{}'.format('_'.join(groupby_feats), feat): (feat, 'median'),
            #'sum_{}_price'.format('_'.join(groupby_feats)): ('price', 'sum')
        }
        return df[groupby_feats + [feat]].groupby(groupby_feats).agg(
            **agg_params
        ).reset_index()

    df['czynsz_num'] = df.czynsz.map(parse_czynsz)
    
    df['area_num'] = df.area.map(parse_area)
    area_num_99 = np.percentile(df['area_num'], 99)
    df['area_norm'] = df['area_num'].map(lambda x: x if x <= area_num_99 else area_num_99)
    df['area_num_log'] = np.log(df['area_num'])
    
    df['price_m2'] = df['price'] / df['area_num']
    
    df['province'] = df['location'].map(lambda x: x[0])
    df['city'] = df['location'].map(parse_location_city)
    df['floors_in_building_num'] = df['floors_in_building'].map(parse_floors_in_building)
    df['build_year'] = df['rok budowy'].fillna(-1).astype('int')
    
    floors_dict = {'parter': 0, '> 10': 11, 'poddasze': -2, 'suterena': -1}
    df['floor_num'] = df['floor'].map(lambda x: floors_dict.get(x, x)).fillna(-10).astype('int')
    
    
    if 'city_area' not in df.columns:
        df = pd.merge(df, city_stats, on='city', how='left')
    if 'province_population' not in df.columns:
        df = pd.merge(df, province_stats, on='province', how='left')
    
    miasta_woj = ['Białystok', 'Bydgoszcz', 'Gdańsk', 'Gorzów Wielkopolski', 'Katowice', 'Kielce', 'Kraków', 'Lublin',
    'Łódź', 'Olsztyn', 'Opole', 'Poznań', 'Rzeszów', 'Szczecin', 'Toruń', 'Warszawa', 'Wrocław', 'Zielona Góra']
    
    df['miasta_woj'] = df['city'].isin(miasta_woj)
    
    #Agregacje
    groupby_city_price = df_groupby_feat(df, ['city'], 'price')        
    if 'median_city_price' not in df:
        df = pd.merge(df, groupby_city_price, on='city', how='left')
        
    groupby_county_price = df_groupby_feat(df, ['county'], 'price')        
    if 'median_county_price' not in df:
        df = pd.merge(df, groupby_county_price, on='county', how='left')
    
    #groupby_city_pricem2 = df_groupby_feat(df, ['city'], 'price_m2')        
    #if 'median_county_price_m2' not in df:
    #    df = pd.merge(df, groupby_city_pricem2, on='city', how='left')
        
    #groupby_county_pricem2 = df_groupby_feat(df, ['county'], 'price_m2')        
    #if 'median_county_price_m2' not in df:
    #    df = pd.merge(df, groupby_county_pricem2, on='county', how='left')
        
    #groupby_province_price = df_group_price(df, ['province'])        
    #if 'median_province_price' not in df:
    #    df = pd.merge(df, groupby_province_price, on='province', how='left') 
    

    df['city_cat'] = df['city'].factorize()[0]
    df['county_cat'] = df['county'].factorize()[0]
    df['province_cat'] = df['province'].factorize()[0]
    
    
    cat_feats = {
        "materiał budynku": "build_material_cat",
        "okna": "window_cat",
        "stan wykończenia": "property_completion_cat",
        "rodzaj zabudowy": "property_type_cat",
        "ogrzewanie": "property_heating_cat",
        "forma własności": "own_property_cat"
     }    
    
    for feat_name, feat_new_name in cat_feats.items():
        df[feat_new_name] = df[feat_name].factorize()[0]
        
        #OHE
        df_dummies = pd.get_dummies(df[feat_name])
        df_dummies.columns = ['{0}_{1}'.format(feat_new_name, x) for x in df_dummies.columns]
        pd.concat([df, df_dummies], axis=1)
        
    stats = df['stats'].apply(pd.Series)
    df = pd.concat([df, stats], axis=1)
    dict_created_at={
        'ponad 14 dni temu':18,  
        '23.10.2018':17,
        '24.10.2018':16,
        '25.10.2018':15,
        '26.10.2018':14, 
        '27.10.2018':13,
        '28.10.2018':12,
        '29.10.2018':11,
        '30.10.2018':10,
        '31.10.2018':9,
        '01.11.2018':8,    
        '02.11.2018':7,
        '03.11.2018':6,
        '04.11.2018':5,
        '05.11.2018':4,
        '06.11.2018':3,
        '07.11.2018':2,
        '08.11.2018':1,
    }
        
    df['created_at_cat'] = df['created_at'].map(dict_created_at)
    #df['created_at_cat'] = df['created_at'].factorize()[0]
    #df['visit_ads_num'] = df.visit_ads.fillna(-1).astype('int')  
    df['visit_ads_num'] = df.visit_ads.map(lambda x: np.log(int(x) + 10) if not isinstance(x, float)  else -1)
    
    
    #Starter3
    #Location
    for i in range(5):
        df["loc{}".format(i)] = df["location"].map(lambda x: x[i] if len(x) > i else "")      
    
    df['loc01'] = df['loc0'] + df['loc1']
    df['loc012'] = df['loc0'] + df['loc1'] + df['loc2']
    df['loc12'] = df['loc1'] + df['loc2']
    
    #cat location
    for i in range(5):
        df["loc{}_cat".format(i)] = df["loc{}".format(i)].factorize()[0]
    df["loc01_cat"] = df['loc01'].factorize()[0]
    df["loc012_cat"] = df['loc012'].factorize()[0] 
    df["loc12_cat"] = df['loc12'].factorize()[0] 
    
    def groupby_location(df, loc, feat):
        groupby_feat = df_groupby_feat(df, [loc], feat)        
        if 'median_{}_price'.format(loc) not in df:
            return pd.merge(df, groupby_feat, on='{}'.format(loc), how='left')
    
    #df = groupby_location(df, 'loc01', 'price')    
    #df = groupby_location(df, 'loc12')
    
    #Starter 4
    
    df['security'] = df['system alarmowy'] | df['rolety antywłamaniowe'] | df['drzwi / okna antywłamaniowe']
    
    df['area_per_room'] = df['area_norm'] / df["rooms"]
    
    years = [1970, 1980, 1990, 2000, 2005, 2010, 2012, 2014, 2016, 2017]
    
    def build_year_norm(year):
        if year < 1970: return 1900
        if year > 2017: return 2018

        for idx in range(len(years) - 1):
            if years[idx+1] > year >= years[idx]:
                return years[idx]

    df["build_year_norm"] = df["build_year"].map(build_year_norm)

    
    big_cities = {'Poznań', 'Sopot', 'Wrocław', 'Kraków', 'Gdańsk', 'Gdynia', 'Opole', 'Katowice',  'Częstochowa', 'Szczecin', 'Kalisz', 'Łódź', 'Olsztyn', 'Warszawa'}
    for city in big_cities:
        df[city] = df['city'] == city
        df['big_city'] = df['city'].map(lambda x: x in big_cities)
        
    
    #location
    df_val_cnts = df['loc12'].value_counts()
    loc12_vals = set(df_val_cnts[ df_val_cnts > 100].index.values)
    for item in loc12_vals:
        df[item] = df['loc12'] == item
        
    
    #primary_market
    
    def is_primary_market_conc(df, feat):
        df['is_primary_market_{}'.format(feat)] = df[ ['is_primary_market', feat] ].apply(
            lambda x: '{}_{}'.format(x['is_primary_market'], x[feat]), axis=1
        )
        df['is_primary_market_{}_cat'.format(feat)] = df['is_primary_market_{}'.format(feat)].factorize()[0]

        return df
    
    df = is_primary_market_conc(df, 'rooms')
    df = is_primary_market_conc(df, 'city')
    df = is_primary_market_conc(df, 'rodzaj zabudowy') 
    
    #agregacje price_m2
    groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_rooms'], 'price_m2')
    df = pd.merge(df, groupby_price_m2, on='is_primary_market_rooms', how='left')
    
    #groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_city'], 'price_m2')
    #df = pd.merge(df, groupby_price_m2, on='is_primary_market_city', how='left')
    
    groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_rodzaj zabudowy'], 'price_m2')
    df = pd.merge(df, groupby_price_m2, on='is_primary_market_rodzaj zabudowy', how='left')
    

                                                                   
    return df

# %%
ls ../input_ext/
# Out:
# city_stats.csv  region_stats.csv

# %%
ls ../input/
# Out:
# big_train_warsaw_property.h5  train_data.h5@
# test_warsaw_property.h5       train_warsaw_property.h5

# %%
df_train = pd.read_hdf('../input/big_train_warsaw_property.h5')
df_test = pd.read_hdf('../input/test_warsaw_property.h5')
df_org = pd.concat([df_train, df_test])

#External city and region data (Wikipedia)
city_stats = pd.read_csv('../input_ext/city_stats.csv')
city_stats.drop('Województwo', axis=1, inplace=True)
city_stats.columns = ['city', 'county', 'city_area', 'city_population', 'city_density']

province_stats = pd.read_csv('../input_ext/province_stats.csv')
province_stats.drop('Lp.', axis=1, inplace=True)
province_stats.columns = ['province', 'province_population', 'province_men_population', 'province_women_population']

print(df_train.shape, df_test.shape, df_org.shape)

del df_train, df_test
gc.collect
# Out:
# (46489, 53) (46275, 52) (92764, 53)
# <function gc.collect(generation=2)>

# %% [markdown]
# # BASIC MODEL - Kaggle Score: 182576.93612

# %%
df = feature_engineering(df_org.copy())
print(df.shape)
df.sample(3)
# Out:
# (92764, 343)
#           id                                           location  is_private  \
# 22279  44366  [małopolskie, Kraków, Bronowice, Gabrieli Zapo...           0
# 6975   13911  [kujawsko-pomorskie, Grudziądz, Rządz, ul. Syb...          -1
# 56388  19892                [dolnośląskie, Wrocław, Stabłowice]           0
#
#        piekarnik  garaż  monitoring / ochrona  rolety antywłamaniowe  \
# 22279      False  False                 False                  False
# 6975       False  False                 False                  False
# 56388      False  False                  True                  False
#
#        kuchenka  taras  balkon  ogródek  dwupoziomowe  system alarmowy  \
# 22279     False  False    True    False         False            False
# 6975      False   True   False    False         False            False
# 56388     False   True    True    False         False            False
#
#        pom. użytkowe  klimatyzacja  tarasy  teren zamknięty  internet  winda  \
# 22279           True         False   False            False      True   True
# 6975           False         False   False            False      True   True
# 56388          False         False   False            False      True   True
#
#        telefon  pralka  piwnica  ochrona  telewizja kablowa  telewizor  \
# 22279    False   False    False    False               True      False
# 6975      True   False    False    False               True      False
# 56388    False   False    False    False               True      False
#
#        lodówka  domofon / wideofon  oddzielna kuchnia  zmywarka  \
# 22279    False               False               True     False
# 6975     False               False              False     False
# 56388    False               False              False     False
#
#        garaż/miejsce parkingowe  meble  drzwi / okna antywłamaniowe  \
# 22279                      True   True                        False
# 6975                       True  False                        False
# 56388                      True  False                        False
#
#        plan zagospodarowania:     price      area  rooms   floor  \
# 22279                   False  420000.0     58 m²      2       1
# 6975                    False  279461.5  63,95 m²      3  parter
# 56388                   False       NaN  45,42 m²      2       2
#
#       floors_in_building dostępne od rok budowy materiał budynku        okna  \
# 22279             (z 10)         NaN        NaN              NaN  plastikowe
# 6975               (z 4)         NaN       2019              NaN  plastikowe
# 56388              (z 4)         NaN       2019              NaN  plastikowe
#
#       data rozpoczęcia stan inwestycji liczba kondygnacji stan wykończenia  \
# 22279              NaN             NaN                NaN  do zamieszkania
# 6975               NaN             NaN                NaN   do wykończenia
# 56388              NaN             NaN                NaN              NaN
#
#        czynsz  rodzaj zabudowy ogrzewanie forma własności  \
# 22279  370 zł             blok     gazowe             NaN
# 6975   450 zł             blok   miejskie  pełna własność
# 56388     NaN  apartamentowiec   miejskie             NaN
#
#                                                    stats  \
# 22279  {'ID': 108403032, 'visit_ads': '463', 'created...
# 6975   {'ID': 109429584, 'created_at': 'ponad 14 dni ...
# 56388  {'ID': 112062736, 'visit_ads': '186', 'created...
#
#                                                     text  is_primary_market  \
# 22279  Opis Nowodworski Estates ma przyjemność zaprez...              False
# 6975   Opis NOWY RZĄDZ- NOWA INWESTYCJA!!! Nowe miesz...               True
# 56388  Opis Rodzinna inwestycja w najbardziej zielone...               True
#
#        czynsz_num  area_num  area_norm  area_num_log    price_m2  \
# 22279       370.0     58.00      58.00      4.060443  7241.37931
# 6975        450.0     63.95      63.95      4.158102  4370.00000
# 56388         NaN     45.42      45.42      3.815953         NaN
#
#                  province       city  floors_in_building_num  build_year  \
# 22279         małopolskie     Kraków                    10.0          -1
# 6975   kujawsko-pomorskie  Grudziądz                     4.0        2019
# 56388        dolnośląskie    Wrocław                     4.0        2019
#
#        floor_num        county  city_area  city_population  city_density  \
# 22279          1     Kraków[a]     326.85         767348.0        2348.0
# 6975           0  Grudziądz[a]      57.76          95629.0        1656.0
# 56388          2    Wrocław[a]     292.82         638586.0        2181.0
#
#        province_population  province_men_population  \
# 22279              3372618                  1636707
# 6975               2086210                  1010973
# 56388              2904207                  1396318
#
#        province_women_population  miasta_woj  mean_city_price  \
# 22279                    1735911        True    529502.500000
# 6975                     1075237       False    236839.328125
# 56388                    1507889        True    396989.687500
#
#        median_city_price  mean_county_price  median_county_price  city_cat  \
# 22279           416305.0      529502.500000             416305.0       162
# 6975            219226.5      236839.328125             219226.5        17
# 56388           361227.0      396989.687500             361227.0         4
#
#        county_cat  province_cat  build_material_cat  window_cat  \
# 22279         100             5                  -1           0
# 6975           16             1                  -1           0
# 56388           3             0                  -1           0
#
#        property_completion_cat  property_type_cat  property_heating_cat  \
# 22279                        1                  1                     0
# 6975                         0                  1                     1
# 56388                       -1                  4                     1
#
#        own_property_cat         ID         created_at  updated_at visit_ads  \
# 22279                -1  108403032  ponad 14 dni temu  01.11.2018       463
# 6975                  0  109429584  ponad 14 dni temu  02.11.2018       NaN
# 56388                -1  112062736  ponad 14 dni temu  03.11.2018       186
#
#        created_at_cat  visit_ads_num                loc0       loc1  \
# 22279              18       6.159095         małopolskie     Kraków
# 6975               18      -1.000000  kujawsko-pomorskie  Grudziądz
# 56388              18       5.278115        dolnośląskie    Wrocław
#
#              loc2                 loc3 loc4                        loc01  \
# 22279   Bronowice  Gabrieli Zapolskiej                 małopolskieKraków
# 6975        Rządz        ul. Sybiraków       kujawsko-pomorskieGrudziądz
# 56388  Stabłowice                                    dolnośląskieWrocław
#
#                                  loc012              loc12  loc0_cat  \
# 22279        małopolskieKrakówBronowice    KrakówBronowice         5
# 6975   kujawsko-pomorskieGrudziądzRządz     GrudziądzRządz         1
# 56388     dolnośląskieWrocławStabłowice  WrocławStabłowice         0
#
#        loc1_cat  loc2_cat  loc3_cat  loc4_cat  loc01_cat  loc012_cat  \
# 22279        95       553      4298         0         97         961
# 6975         16       129      1750         0         16         139
# 56388         3        17         1         0          3          17
#
#        loc12_cat  security  area_per_room  build_year_norm  Wrocław  big_city  \
# 22279        961     False      29.000000           1900.0    False      True
# 6975         139     False      21.316667           2018.0    False     False
# 56388         17     False      22.710000           2018.0    False      True
#
#        Opole  Warszawa  Kalisz  Częstochowa  Olsztyn  Sopot  Katowice  Poznań  \
# 22279  False     False   False        False    False  False     False   False
# 6975   False     False   False        False    False  False     False   False
# 56388  False     False   False        False    False  False     False   False
#
#        Szczecin  Kraków  Gdynia   Łódź  Gdańsk  LublinCentrum  \
# 22279     False    True   False  False   False          False
# 6975      False   False   False  False   False          False
# 56388     False   False   False  False   False          False
#
#        KrakówKazimierz  poznańskiSwarzędz  WarszawaWilanów  \
# 22279            False              False            False
# 6975             False              False            False
# 56388            False              False            False
#
#        CzęstochowaTysiąclecie  wrocławskiKiełczów  \
# 22279                   False               False
# 6975                    False               False
# 56388                   False               False
#
#        ostrowskiOstrów Wielkopolski  GdańskOliwa  BiałystokWysoki Stoczek  \
# 22279                         False        False                    False
# 6975                          False        False                    False
# 56388                         False        False                    False
#
#        wrocławskiSiechnice  KatowiceBrynów  wejherowskiWejherowo  \
# 22279                False           False                 False
# 6975                 False           False                 False
# 56388                False           False                 False
#
#        PoznańBułgarska 59  GliwiceStare Gliwice  LublinSzerokie  \
# 22279               False                 False           False
# 6975                False                 False           False
# 56388               False                 False           False
#
#        OpoleŚródmieście  KrakówBronowice  wejherowskiRumia  \
# 22279             False             True             False
# 6975              False            False             False
# 56388             False            False             False
#
#        BiałystokNowe Miasto  WrocławKrzyki  KatowiceDolina Trzech Stawów  \
# 22279                 False          False                         False
# 6975                  False          False                         False
# 56388                 False          False                         False
#
#        SosnowiecZagórze  LublinWęglinek  KatowiceKostuchna  GdyniaOksywie  \
# 22279             False           False              False          False
# 6975              False           False              False          False
# 56388             False           False              False          False
#
#        WrocławHuby  ToruńMokre  GdańskChełm  GdańskŚródmieście  \
# 22279        False       False        False              False
# 6975         False       False        False              False
# 56388        False       False        False              False
#
#        KrakówBronowice Małe  WrocławŚródmieście  BydgoszczBłonie  \
# 22279                 False               False            False
# 6975                  False               False            False
# 56388                 False               False            False
#
#        Zielona Góra  BiałystokCentrum  gdańskiPruszcz Gdański  \
# 22279         False             False                   False
# 6975          False             False                   False
# 56388         False             False                   False
#
#        WarszawaBiałołęka  piaseczyńskiJózefosław  WarszawaTargówek  \
# 22279              False                   False             False
# 6975               False                   False             False
# 56388              False                   False             False
#
#        WrocławMaślice  KrakówDębniki  GdyniaWitomino  RzeszówSłocina  \
# 22279           False          False           False           False
# 6975            False          False           False           False
# 56388           False          False           False           False
#
#        ToruńBydgoskie Przedmieście  PoznańGórczyn  ToruńKoniuchy  \
# 22279                        False          False          False
# 6975                         False          False          False
# 56388                        False          False          False
#
#        BydgoszczKapuściska  WarszawaPraga-Północ  RzeszówDrabinianka  \
# 22279                False                 False               False
# 6975                 False                 False               False
# 56388                False                 False               False
#
#        kamieńskiMiędzyzdroje  świdnickiŚwidnica  Zielona GóraCentrum  \
# 22279                  False              False                False
# 6975                   False              False                False
# 56388                  False              False                False
#
#        WrocławStare Miasto  KielceŚlichowice  GdańskSiedlce  WrocławSwojczyce  \
# 22279                False             False          False             False
# 6975                 False             False          False             False
# 56388                False             False          False             False
#
#        WrocławKlecina  BydgoszczŚródmieście  WarszawaSaska Kępa  \
# 22279           False                 False               False
# 6975            False                 False               False
# 56388           False                 False               False
#
#        BydgoszczBielawy  GdyniaObłuże  PoznańWinogrady  stargardzkiStargard  \
# 22279             False         False            False                False
# 6975              False         False            False                False
# 56388             False         False            False                False
#
#        PoznańŁazarz  PoznańPodolany  GdyniaŚródmieście  PoznańCentrum  \
# 22279         False           False              False          False
# 6975          False           False              False          False
# 56388         False           False              False          False
#
#        tatrzańskiZakopane  WarszawaOchota  SzczecinGumieńce  \
# 22279               False           False             False
# 6975                False           False             False
# 56388               False           False             False
#
#        WrocławPlac Grunwaldzki  GliwiceCentrum  WarszawaBemowo  \
# 22279                    False           False           False
# 6975                     False           False           False
# 56388                    False           False           False
#
#        KrakówBieżanów-Prokocim  KielceCentrum  PoznańNowe Miasto  \
# 22279                    False          False              False
# 6975                     False          False              False
# 56388                    False          False              False
#
#        GdyniaMały Kack  WarszawaŻoliborz  SzczecinWarszewo  \
# 22279            False             False             False
# 6975             False             False             False
# 56388            False             False             False
#
#        KrakówKliny-Zacisze  głogowskiGłogów  GdańskUjeścisko  WrocławJagodno  \
# 22279                False            False            False           False
# 6975                 False            False            False           False
# 56388                False            False            False           False
#
#        WarszawaGocław  Dąbrowa GórniczaGołonóg  WrocławGaj  LublinDziesiąta  \
# 22279           False                    False       False            False
# 6975            False                    False       False            False
# 56388           False                    False       False            False
#
#        BiałystokBojary  inowrocławskiInowrocław  wołomińskiZąbki  \
# 22279            False                    False            False
# 6975             False                    False            False
# 56388            False                    False            False
#
#        ToruńNa Skarpie  ŁódźPolesie  KrakówRuczaj  GdańskJelitkowo  \
# 22279            False        False         False            False
# 6975             False        False         False            False
# 56388            False        False         False            False
#
#        PoznańWilczak  GdańskStare Miasto  KrakówSalwator  KrakówMistrzejowice  \
# 22279          False               False           False                False
# 6975           False               False           False                False
# 56388          False               False           False                False
#
#        BiałystokAntoniuk  Grudziądz  GdyniaRedłowo  PoznańRataje  \
# 22279              False      False          False         False
# 6975               False      False          False         False
# 56388              False      False          False         False
#
#        BydgoszczBartodzieje  PoznańStare Miasto  PoznańWilda  WarszawaPowiśle  \
# 22279                 False               False        False            False
# 6975                  False               False        False            False
# 56388                 False               False        False            False
#
#        tczewskiTczew  WrocławFabryczna  WarszawaWawer  będzińskiBędzin  \
# 22279          False             False          False            False
# 6975           False             False          False            False
# 56388          False             False          False            False
#
#        pruszkowskiPruszków  GdańskJasień  KrakówŁobzów  ŁódźWidzew  \
# 22279                False         False         False       False
# 6975                 False         False         False       False
# 56388                False         False         False       False
#
#        krakowskiSkawina  lęborskiLębork  KrakówWzgórza Krzesławickie  \
# 22279             False           False                        False
# 6975              False           False                        False
# 56388             False           False                        False
#
#        KrakówPodgórze  puckiJastarnia  WarszawaUrsynów  kołobrzeskiKołobrzeg  \
# 22279           False           False            False                 False
# 6975            False           False            False                 False
# 56388           False           False            False                 False
#
#        WarszawaMokotów  ToruńRubinkowo  KrakówStare Miasto  \
# 22279            False           False               False
# 6975             False           False               False
# 56388            False           False               False
#
#        BydgoszczSzwederowo  BydgoszczGlinki  KatowiceOsiedle Paderewskiego  \
# 22279                False            False                          False
# 6975                 False            False                          False
# 56388                False            False                          False
#
#        ToruńChełmińskie Przedmieście  dzierżoniowskiDzierżoniów  GdyniaOrłowo  \
# 22279                          False                      False         False
# 6975                           False                      False         False
# 56388                          False                      False         False
#
#        Gliwice  CzęstochowaParkitka  LublinCzuby  SopotDolny  \
# 22279    False                False        False       False
# 6975     False                False        False       False
# 56388    False                False        False       False
#
#        tarnogórskiTarnowskie Góry  ZabrzeCentrum  KrakówStare Podgórze  \
# 22279                       False          False                 False
# 6975                        False          False                 False
# 56388                       False          False                 False
#
#        WrocławZłotniki  Gorzów WielkopolskiGórczyn  piaseczyńskiPiaseczno  \
# 22279            False                       False                  False
# 6975             False                       False                  False
# 56388            False                       False                  False
#
#        KrakówWola Duchacka  BydgoszczOsiedle Leśne  LublinLSM  LublinFelin  \
# 22279                False                   False      False        False
# 6975                 False                   False      False        False
# 56388                False                   False      False        False
#
#        KrakówKrowodrza  GdańskWrzeszcz  będzińskiSiewierz  \
# 22279            False           False              False
# 6975             False           False              False
# 56388            False           False              False
#
#        KatowiceŚródmieście  PoznańGrunwald  ŁódźGórna  \
# 22279                False           False      False
# 6975                 False           False      False
# 56388                False           False      False
#
#        KatowiceOsiedle Tysiąclecia  TychyŻwaków  PoznańNaramowice  \
# 22279                        False        False             False
# 6975                         False        False             False
# 56388                        False        False             False
#
#        KrakówŚródmieście  BytomCentrum  WrocławStabłowice  ełckiEłk  \
# 22279              False         False              False     False
# 6975               False         False              False     False
# 56388              False         False               True     False
#
#        KatowicePiotrowice  KrakówWola Justowska  KrakówNowa Huta  \
# 22279               False                 False            False
# 6975                False                 False            False
# 56388               False                 False            False
#
#        BydgoszczFordon  SzczecinCentrum  wołomińskiMarki  KrakówCzyżyny  \
# 22279            False            False            False          False
# 6975             False            False            False          False
# 56388            False            False            False          False
#
#        ToruńJakubskie Przedmieście  WarszawaPraga-Południe  \
# 22279                        False                   False
# 6975                         False                   False
# 56388                        False                   False
#
#        KrakówPrądnik Biały  GdańskŁostowice  lubińskiLubin  SzczecinPogodno  \
# 22279                False            False          False            False
# 6975                 False            False          False            False
# 56388                False            False          False            False
#
#        WrocławTarnogaj  GdańskKowale  WarszawaŚródmieście  SosnowiecCentrum  \
# 22279            False         False                False             False
# 6975             False         False                False             False
# 56388            False         False                False             False
#
#        Rzeszów  KrakówOlsza  WarszawaWłochy  KatowiceWełnowiec  \
# 22279    False        False           False              False
# 6975     False        False           False              False
# 56388    False        False           False              False
#
#        LublinŚródmieście  namysłowskiNamysłów  WarszawaBielany  Kielce  \
# 22279              False                False            False   False
# 6975               False                False            False   False
# 56388              False                False            False   False
#
#        GdańskPrzymorze  BydgoszczCentrum  BydgoszczGórzyskowo  WarszawaUrsus  \
# 22279            False             False                False          False
# 6975             False             False                False          False
# 56388            False             False                False          False
#
#        GdańskZaspa  wejherowskiReda  ŁódźBałuty  LublinWrotków  GdańskMorena  \
# 22279        False            False       False          False         False
# 6975         False            False       False          False         False
# 56388        False            False       False          False         False
#
#        BydgoszczWyżyny  KrakówGrzegórzki  ŁódźŚródmieście  PoznańJeżyce  \
# 22279            False             False            False         False
# 6975             False             False            False         False
# 56388            False             False            False         False
#
#        poznańskiZalasewo  SosnowiecPogoń  wielickiWieliczka  WrocławPsie Pole  \
# 22279              False           False              False             False
# 6975               False           False              False             False
# 56388              False           False              False             False
#
#        SzczecinŚródmieście  KrakówPrądnik Czerwony  SzczecinNiebuszewo  \
# 22279                False                   False               False
# 6975                 False                   False               False
# 56388                False                   False               False
#
#        PoznańPiątkowo  KatowiceJózefowiec  WarszawaWola  KrakówKurdwanów  \
# 22279           False               False         False            False
# 6975            False               False         False            False
# 56388           False               False         False            False
#
#        SopotGórny  poznańskiLuboń  Wrocławul. Brzoskwiniowa  \
# 22279       False           False                     False
# 6975        False           False                     False
# 56388       False           False                     False
#
#        WrocławMuchobór Wielki is_primary_market_rooms  \
# 22279                   False                 False_2
# 6975                    False                  True_3
# 56388                   False                  True_2
#
#        is_primary_market_rooms_cat is_primary_market_city  \
# 22279                            3           False_Kraków
# 6975                             0         True_Grudziądz
# 56388                            5           True_Wrocław
#
#        is_primary_market_city_cat is_primary_market_rodzaj zabudowy  \
# 22279                         222                        False_blok
# 6975                           22                         True_blok
# 56388                           8              True_apartamentowiec
#
#        is_primary_market_rodzaj zabudowy_cat  \
# 22279                                      3
# 6975                                       8
# 56388                                      7
#
#        mean_is_primary_market_rooms_price_m2  \
# 22279                            6437.640518
# 6975                             6057.419592
# 56388                            6727.439805
#
#        median_is_primary_market_rooms_price_m2  \
# 22279                              5813.953488
# 6975                               5600.000000
# 56388                              6046.991315
#
#        mean_is_primary_market_rodzaj zabudowy_price_m2  \
# 22279                                      5587.835882
# 6975                                       5915.493739
# 56388                                      7203.191746
#
#        median_is_primary_market_rodzaj zabudowy_price_m2
# 22279                                        5201.773009
# 6975                                         5690.000186
# 56388                                        6103.313169

# %%
feats = ['id']
model = DummyRegressor()
model.fit(df_train[feats].values, df_train['price'])
y_pred = model.predict(df_test[feats].values)

df_test['price'] = y_pred
df_test[ ['id', 'price'] ].to_csv('../output/DummyRegressor.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-319e7d7f2219> in <module>
#       1 feats = ['id']
#       2 model = DummyRegressor()
# ----> 3 model.fit(df_train[feats].values, df_train['price'])
#       4 y_pred = model.predict(df_test[feats].values)
#       5
#
# NameError: name 'df_train' is not defined

# %%
#msno.bar(df_train.iloc[:,40:50])

# %% [markdown]
# # ⭐ DAY 4 MODEL = Score: 51517.18706 Public score: 54286.18086

# %% [markdown]
# ## 🤖 MLflow

# %%
# !mlflow ui --backend-store-uri file:///home/jovyan/dwsolutions/property_warsaw/notebooks/mlruns

# %% [markdown]
#  ### [Dashboard](/hub/user-redirect/proxy/5000/)

# %%
start_experiment(df, 'catboost_hyper', scoring=mean_absolute_error,
                 filename='catboost',
                 results=True,
                 export=True,
                 mlflow_save=True)
# Out:
# Working on "catboost_6" experiment
# 0it [00:31, ?it/s]
# catboost_6.csv save successfully in "output" folder
# Experiment catboost_6 recorded
# (50682.823719676235, 0.0)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1612
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0865
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0802
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0588
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num_log
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0509
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_is_primary_market_rodzaj zabudowy_price_m2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0364
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0360
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0349
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0301
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0293
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 visit_ads_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0189
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_per_room
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0178
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_population
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0171
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 loc2_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0171
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0170
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_primary_market
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0168
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_completion_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0163
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors_in_building_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0160
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 winda
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0145
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_heating_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
start_experiment(df,
                 'catboost_hyper',
                 scoring=mean_absolute_error,
                 filename='catboost',
                 results=False,
                 export=True,
                 mlflow_save=False)
# Out:
# Working on "catboost_5" experiment
# catboost_5.csv save successfully in "output" folder
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1058
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num_log
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0843
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0540
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0532
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0511
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_is_primary_market_rodzaj zabudowy_price_m2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0429
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0359
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0306
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0275
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 visit_ads_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0237
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_area
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0232
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0172
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors_in_building_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0169
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_completion_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_heating_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_per_room
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0164
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_density
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0155
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 loc2_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0130
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
start_experiment(df,
                 'catboost_hyper',
                 scoring=mean_absolute_error,
                 filename='catboost',
                 results=True,
                 export=False,
                 mlflow_save=True)
# Out:
# Working on "catboost_3" experiment
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-7febb5c937b5> in <module>
# ----> 1 start_experiment(df,
#       2                  'catboost_hyper',
#       3                  scoring=mean_absolute_error,
#       4                  filename='catboost',
#       5                  results=True,
#
# <ipython-input-50-8ca56f8692c4> in start_experiment(df, model_or_id, scoring, filename, results, export, mlflow_save)
#     155     #results
#     156     if results:
# --> 157         result = check_model(X, y, model, scoring)
#     158
#     159     model.fit(X.values, y_log.values)
#
# <ipython-input-50-8ca56f8692c4> in check_model(X, y, model, scoring)
#     106     scores = []
#     107     for train_idx, test_idx in tqdm(cv.split(X)):
# --> 108         X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
#     109         y_log_train, y_test = np.log(y).iloc[train_idx], y.iloc[test_idx]
#     110
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
import future.utils

# %%
utils.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-25f1c259dd64> in <module>
# ----> 1 utils.__version__
#
# NameError: name 'utils' is not defined

# %%
import future

# %%
future.__version__
# Out:
# '0.18.2'

# %%
future.utils.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-71fa9d48c6fd> in <module>
# ----> 1 future.utils.__version__
#
# AttributeError: module 'future.utils' has no attribute '__version__'

# %%
future
# Out:
# <module 'future' from '/opt/conda/lib/python3.8/site-packages/future/__init__.py'>

# %%
import future
from future import utils

print(utils.PY2)
print(utils.PY34_PLUS)
print(future.__version__)
# Out:
# False
# True
# 0.18.2

# %%
start_experiment(df, 'catboost_light', scoring=mean_absolute_error,
                 filename='catboost',
                 results=False,
                 export=False,
                 mlflow_save=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-7c27ca3b37cc> in <module>
# ----> 1 start_experiment(df, 'catboost_light', scoring=mean_absolute_error,
#       2                  filename='catboost',
#       3                  results=False,
#       4                  export=False,
#       5                  mlflow_save=True)
#
# <ipython-input-24-d19174baf3b7> in start_experiment(df, model_or_id, scoring, filename, results, export, mlflow_save, blacklist_extended)
#     138     """
#     139     if mlflow_save:
# --> 140         assert results, '"mlflow_save" argument can be set to True only if "results" argument is also set to True'
#     141
#     142     filename = get_filename(filename)
#
# AssertionError: "mlflow_save" argument can be set to True only if "results" argument is also set to True

# %%
help(start_experiment)
# Out:
# Help on function start_experiment in module __main__:
#
# start_experiment(df, model_or_id, scoring=<function mean_absolute_error at 0x7f5b01144550>, filename='catboost', results=True, export=False, mlflow_save=True, blacklist_extended=None)
#     Main function to conducts experiment.
#
#     Main feature are:
#     record experiment data using MLflow - "mlflow_save" argument,
#     showing results based on selected metric - "results" argument,
#     exporting forecast to csv file - "export" argument.
#     All above argument are boolean and can be set independently according to expected output.
#     Mlflow_save argument can be set to True only if results argument is also set to True.
