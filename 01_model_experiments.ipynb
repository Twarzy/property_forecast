# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold
from sklearn.dummy import DummyRegressor

import eli5
import catboost

import mlflow
import missingno as msno
import gc
from os.path import exists
from tqdm import tqdm

pd.set_option('display.max_columns', None)
mlflow.set_tracking_uri("file:///mlruns")

# %% [markdown]
# ### Defining function used for experiments

# %%
def get_or_create_experiment(experiment_name):
    """Checks if mlflow experiment already exist (if not creates it) and return it."""
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if not experiment:
        mlflow.create_experiment(experiment_name)
        return mlflow.get_experiment_by_name(experiment_name)        
    return experiment


def _eid(experiment_name):
    return get_or_create_experiment(experiment_name).experiment_id


def get_filename(basename):
    """Creates unique filename to prevent overwriting files in target directory when exporting the forecast."""
    counter=0
    filename = '{}_{}'.format(basename, counter)  # filename in format <basename>_<number>.csv
    # Adds +1 to <number> until it gets unique filename
    while exists('output/{}.csv'.format(filename)):
        counter +=1
        filename = '{}_{}'.format(basename, counter)        
    return filename


def get_X_y_log(df, feats):
    """Creates feature matrix, target and logarihtmic vector for model training."""
    X = df[feats]
    y = df['price']
    y_log = np.log(y)    
    return X, y, y_log
    

def get_feats(df, blacklist_extended):
    """Creates training features by taking all number and boolean columns 
    from provided dataframe, reduced by those in blacklist.
    """    
    blacklist = [
        'price',
        'id', 
        'price_m2',
    ]
    # Extra blacklist feature can be added as list in function argument. 
    if blacklist_extended:
        blacklist = blacklist + blacklist_extended       
                         
    num_bool_feats = df.select_dtypes(['number', 'bool'])
    return [x for x in num_bool_feats if x not in blacklist]


def get_model(model_or_id):
    """Returns one of two default models, or alternative one, provided as function argument."""
    if model_or_id == 'catboost_hyper':  # hyper parameters tuned for better forecast, but longer model training.
        model_params = dict(             
            max_depth=8,
            n_estimators=1000,
            learning_rate=0.3,
            random_state=0,
            silent=True,
        )
        return catboost.CatBoostRegressor(**model_params)
    
    elif model_or_id == 'catboost_light':  # hyper parameters tuned for quick results.
        model_params = dict(            
            max_depth=5,
            n_estimators=100,
            random_state=0,
            silent=True,
        )
        return catboost.CatBoostRegressor(**model_params)
    else:
        return model_or_id


def mlflow_experiment(run_name, model, X, feats, result, eli5_result):
    """Uses MLflow tool to record and track important information about experiments.
    Such as model parameters, shape of feature and targe matrix, feats used for model training or eli5 importance of the features
    """
    with mlflow.start_run(experiment_id=_eid('property_forecast'), run_name=run_name) as run:
    
        mlflow.log_params(model.get_params())
        mlflow.log_param("model", str(model).split("(")[0])
        mlflow.log_param("feats", feats)
        mlflow.log_param('X.shape', X.shape)
        
        # artifacts
        with open('outputs/eli5.html', 'w') as f:
            f.write('<html>{}</html>'.format(eli5_result.data))
        mlflow.log_artifact('outputs/eli5.html', 'plot')
                
        # metrics
        mlflow.log_metric('mae_mean', result[0])
        mlflow.log_metric('mae_std', result[1])
              
    print(f'Experiment {run_name} recorded')

    
def check_model(X, y, model, scoring):
    """Evaluate model based on selected metric."""
    cv = KFold(n_splits=5, shuffle=True, random_state=0)
    scores = []    
    for train_idx, test_idx in tqdm(cv.split(X)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_log_train, y_test = np.log(y).iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_log_train)
        y_log_pred = model.predict(X_test)
        y_pred = np.exp(y_log_pred)

        score = scoring(y_test, y_pred)
        scores.append(score)
        
    return (np.mean(scores), np.std(scores))
    
    
def save_forecast_to_csv(model, X_test, df_test, filename):
    """Exports forecast to csv file"""
    y_pred = model.predict(X_test)
    df_test['price'] = np.exp(y_pred)
    
    try:
        df_test[ ['id', 'price'] ].to_csv('output/{}.csv'.format(filename), index=False)
        print('{}.csv save successfully in "output" folder.'.format(filename))
    except:
        print('{}.csv saving ERROR in "output" folder.'.format(filename))
    
    
def start_experiment(df, model_or_id, scoring=mean_absolute_error,
                     filename='catboost',
                     results=True, export=False, mlflow_save=True, blacklist_extended=None):
    """Main function to conducts experiment.
    
    Main feature are:
    record experiment data using MLflow - "mlflow_save" argument,
    showing results based on selected metric - "results" argument,
    exporting forecast to csv file - "export" argument.
    All above argument are boolean and can be set independently according to expected output.
    Mlflow_save argument can be set to True only if results argument is also set to True.
    """
    if mlflow_save:
        assert results, '"mlflow_save" argument can be set to True only if "results" argument is also set to True.'
        
    filename = get_filename(filename)    
    print(f'Working on "{filename}" experiment.')
    
    # Splits dataset into train and test dataframes.     
    df_train = df[ df['price'].notnull() ].fillna(-1)  # takes all rows with "price" column NOT empty
    df_test = df[ df['price'].isnull() ].fillna(-1)  # # takes all rows with "price" column empty
    
    # Gets training features
    feats = get_feats(df, blacklist_extended )
    
    # Gets X and y (feature matrix and target vector).
    X, y, y_log = get_X_y_log(df_train, feats)

    # Gets model
    model = get_model(model_or_id)
    
    # Returning results
    if results:
        result = check_model(X, y, model, scoring)
        
    model.fit(X.values, y_log.values)
    
    # Export forecast to csv.
    if export:
        X_test = df_test[feats].values
        save_forecast_to_csv(model, X_test, df_test, filename)    
  
    eli5_result = eli5.show_weights(model, feature_names=feats, top=100)
    
    #MLflow tracking
    if mlflow_save and results:
        mlflow_experiment(filename, model, X, feats, result, eli5_result)

    if results:
        print(f'MAE SCORE: mean {result[0]}, std {result[1]}')
    return eli5_result

# %% [markdown]
# ## Load data

# %%
df_train = pd.read_hdf('data/train_property.h5')
df_test = pd.read_hdf('data/test_property.h5')
df_org = pd.concat([df_train, df_test])

# External city and province data (Wikipedia)
city_stats = pd.read_csv('external_data/city_stats_wiki.csv')
city_stats.drop('Województwo', axis=1, inplace=True)
city_stats.columns = ['city', 'county', 'city_area', 'city_population', 'city_density']

province_stats = pd.read_csv('external_data/province_stats_wiki.csv')
province_stats.drop('Lp.', axis=1, inplace=True)
province_stats.columns = ['province', 'province_population', 'province_men_population', 'province_women_population']

print(df_train.shape, df_test.shape, df_org.shape)

del df_train, df_test
gc.collect;
# Out:
# (46489, 53) (46275, 52) (92764, 53)

# %%
df_org.sample(5)
# Out:
#           id                                           location  is_private  \
# 86154  86154               [wielkopolskie, poznański, Swarzędz]           0
# 16904  16904                 [dolnośląskie, Wrocław, Fabryczna]           0
# 76365  76365  [pomorskie, Gdańsk, Siedlce, ul. Jacka Malczew...           0
# 63840  63840  [świętokrzyskie, Kielce, Nowy Folwark, Domaszo...           0
# 13944  13944  [kujawsko-pomorskie, Grudziądz, Rządz, ul. Syb...          -1
#
#        piekarnik  garaż  monitoring / ochrona  rolety antywłamaniowe  \
# 86154      False  False                 False                  False
# 16904      False  False                 False                  False
# 76365      False  False                 False                  False
# 63840      False  False                 False                  False
# 13944      False  False                 False                  False
#
#        kuchenka  taras  balkon  ogródek  dwupoziomowe  system alarmowy  \
# 86154     False  False    True    False         False            False
# 16904     False  False   False    False         False            False
# 76365      True  False    True    False         False            False
# 63840     False   True   False    False         False            False
# 13944     False   True   False    False         False            False
#
#        pom. użytkowe  klimatyzacja  tarasy  teren zamknięty  internet  winda  \
# 86154          False         False   False            False     False  False
# 16904          False         False   False            False      True   True
# 76365          False         False   False             True     False   True
# 63840          False         False   False             True     False  False
# 13944          False         False   False            False      True   True
#
#        telefon  pralka  piwnica  ochrona  telewizja kablowa  telewizor  \
# 86154    False   False    False    False              False      False
# 16904     True   False    False    False               True      False
# 76365    False    True    False    False              False      False
# 63840    False   False    False    False              False      False
# 13944     True   False    False    False               True      False
#
#        lodówka  domofon / wideofon  oddzielna kuchnia  zmywarka  \
# 86154    False               False              False     False
# 16904    False                True              False     False
# 76365     True                True              False     False
# 63840    False                True              False     False
# 13944    False               False              False     False
#
#        garaż/miejsce parkingowe  meble  drzwi / okna antywłamaniowe  \
# 86154                     False  False                        False
# 16904                     False  False                        False
# 76365                      True   True                        False
# 63840                      True  False                        False
# 13944                      True  False                        False
#
#        plan zagospodarowania:         price      area  rooms   floor  \
# 86154                   False           NaN  70,50 m²      4       4
# 16904                   False  268236.00000  37,47 m²      3       3
# 76365                   False           NaN     56 m²      3       1
# 63840                   False           NaN  63,10 m²      3  parter
# 13944                   False  319796.59375  73,18 m²      4       3
#
#       floors_in_building    dostępne od rok budowy materiał budynku  \
# 86154              (z 4)            NaN        NaN     wielka płyta
# 16904              (z 4)            NaN        NaN              NaN
# 76365              (z 3)  13 marca 2018       2015           pustak
# 63840              (z 1)            NaN        NaN          silikat
# 13944              (z 4)            NaN       2019              NaN
#
#              okna data rozpoczęcia stan inwestycji liczba kondygnacji  \
# 86154  plastikowe              NaN             NaN                NaN
# 16904         NaN              NaN             NaN                NaN
# 76365  plastikowe              NaN             NaN                NaN
# 63840         NaN              NaN             NaN                NaN
# 13944  plastikowe              NaN             NaN                NaN
#
#       stan wykończenia  czynsz   rodzaj zabudowy ogrzewanie  \
# 86154              NaN     NaN              blok        NaN
# 16904              NaN     NaN              blok        NaN
# 76365  do zamieszkania  550 zł               NaN   miejskie
# 63840   do wykończenia     NaN  dom wolnostojący     gazowe
# 13944   do wykończenia  500 zł              blok   miejskie
#
#              forma własności  \
# 86154  spółdzielcze wł. z kw
# 16904                    NaN
# 76365         pełna własność
# 63840         pełna własność
# 13944         pełna własność
#
#                                                    stats  \
# 86154  {'ID': 108913320, 'visit_ads': '973', 'created...
# 16904  {'ID': 112363296, 'created_at': 'ponad 14 dni ...
# 76365  {'ID': 105989310, 'visit_ads': '879', 'created...
# 63840  {'ID': 106885440, 'visit_ads': '3201', 'create...
# 13944  {'ID': 109430352, 'created_at': 'ponad 14 dni ...
#
#                                                     text  is_primary_market
# 86154  Opis Polecam na sprzedaż mieszkanie czteropoko...              False
# 16904  Opis Kupujący nie ponosi żadnych kosztów , tak...               True
# 76365  Opis LOKALIZACJA: Gdańsk Siedlce. Kilka minut ...              False
# 63840  Opis 24 mieszkania w nowej inwestycji przy uli...               True
# 13944  Opis NOWY RZĄDZ- NOWA INWESTYCJA!!! Nowe miesz...               True

# %% [markdown]
# ## Feature engineering

# %%
def feature_engineering(df):
    """Main feature engineering function. Returned dataframe is ready to model training."""
    
    def parse_czynsz(val):
        """Parses "czynsz" feature object/string to numeric value."""
        if isinstance(val, int): return val
        if isinstance(val, float): return val

        if val[-1] == 'ł':
            return float(val.split('zł')[0].replace(' ', '').replace(',','.'))
        if val[-1] == 'r':
            return float(val.split('eur')[0].replace(' ', '').replace(',','.'))*4.5
    
    
    def parse_area(val):
        """Parses "area" feature from object/string to numeric value."""
        if isinstance(val, int): return val
        if isinstance(val, float): return val

        return float(val.split('m')[0].replace(',','.').replace(' ',''))
    

    def parse_floors_in_building(val):
        """Parses "floors_in_building" feature from object/string to numeric value."""
        if isinstance(val, int): return -1
        if isinstance(val, float): return -1    
        floor = float(val.replace(')','').split()[1])
        return floor if floor < 20 else 25
    
    
    def parse_location_city(val):
        """Using external data from wikipedia checks if value parsed from location feature is city."""
        all_city = city_stats['city'].to_list()
        for city_ in reversed(val):
        # "Józefów" apears more then one time on on all cities list and "Dobra" appears also as a street name.
        # I decided to exclude them, but it can be improved.
            if city_ in ['Dobra', 'Józefów']:
                continue
            if city_ in all_city:
                    return city_
        return 'other' 
        

    def build_year_norm(year):
        """Normalize 'build_year' feature"""
        years = [1970, 1980, 1990, 2000, 2005, 2010, 2012, 2014, 2016, 2017]
        if year < 1970: return 1900
        if year > 2017: return 2018
    
        for idx in range(len(years) - 1):
            if years[idx+1] > year >= years[idx]:
                return years[idx]
    
    
    def df_groupby_feat(df, groupby_feats, feat):
        """Retuns aggregated feature by selected one or more features"""
        agg_params={
            'mean_{}_{}'.format('_'.join(groupby_feats), feat): (feat, 'mean'),
            'median_{}_{}'.format('_'.join(groupby_feats), feat): (feat, 'median'),   
        }
        return df[groupby_feats + [feat]].groupby(groupby_feats).agg(
            **agg_params
        ).reset_index()
    
    
    def concat_and_factorize(df, feat1, feat2):        
        """Concatenate two features and categorize the results"""
        # Concatenate part.
        df['{}_{}'.format(feat1, feat2)] = df[ [feat1, feat2] ].apply(
            lambda x: '{}_{}'.format(x[feat1], x[feat2]), axis=1
        )
        # Categorize part.
        df['{}_{}_cat'.format(feat1, feat2)] = df['{}_{}'.format(feat1, feat2)].factorize()[0]

        return df

    
    # Area
    df['area_num'] = df.area.map(parse_area)
    area_num_99 = np.percentile(df['area_num'], 99)
    df['area_norm'] = df['area_num'].map(lambda x: x if x <= area_num_99 else area_num_99)
    df['area_num_log'] = np.log(df['area_num'])
    df['price_m2'] = df['price'] / df['area_num'] 
    
    # Rooms
    df['area_per_room'] = df['area_norm'] / df["rooms"]    

    # Location 
    province_cities = ['Białystok', 'Bydgoszcz', 'Gdańsk', 'Gorzów Wielkopolski', 'Katowice', 'Kielce', 'Kraków', 'Lublin',
    'Łódź', 'Olsztyn', 'Opole', 'Poznań', 'Rzeszów', 'Szczecin', 'Toruń', 'Warszawa', 'Wrocław', 'Zielona Góra']
    
    df['province'] = df['location'].map(lambda x: x[0])
    df['city'] = df['location'].map(parse_location_city)
    df['province_city'] = df['city'].isin(province_cities)
    
    # Merging main dataframe with external data about cities.
    if 'city_area' not in df.columns:
        df = pd.merge(df, city_stats, on='city', how='left')
    # Merging main dataframe with external data about provinces.    
    if 'province_population' not in df.columns:
        df = pd.merge(df, province_stats, on='province', how='left')
        
    """'Location' feature is list cointaining elements describing property location in order
    from general to specyfic, which could be [<province>, <county>, <city>, <district> and <street>].
    """    
    for i in range(5):
        # We can assume that "loc1" is likely province, "loc2" is likely county and so on.
        df["loc{}".format(i)] = df["location"].map(lambda x: x[i] if len(x) > i else "")      
    
    df['loc01'] = df['loc0'] + df['loc1']
    df['loc012'] = df['loc0'] + df['loc1'] + df['loc2']
    df['loc12'] = df['loc1'] + df['loc2']
    
    # Categorize location features
    for i in range(5):
        df["loc{}_cat".format(i)] = df["loc{}".format(i)].factorize()[0]
    df["loc01_cat"] = df['loc01'].factorize()[0]
    df["loc012_cat"] = df['loc012'].factorize()[0] 
    df["loc12_cat"] = df['loc12'].factorize()[0]
    
    df['city_cat'] = df['city'].factorize()[0]
    df['county_cat'] = df['county'].factorize()[0]
    df['province_cat'] = df['province'].factorize()[0]
     
    big_cities = {'Poznań', 'Sopot', 'Wrocław', 'Kraków', 'Gdańsk', 'Gdynia', 'Opole', 'Katowice',  'Częstochowa', 'Szczecin', 'Kalisz', 'Łódź', 'Olsztyn', 'Warszawa'}
    for city in big_cities:
        df[city] = df['city'] == city
        df['big_city'] = df['city'].map(lambda x: x in big_cities)
            
    # loc1 is likely to be "city", and loc2 is likely to be "district", so with combining this two
    # we could get for example: WrocławKrzyki, WarszawaŚródmieście, SopotGórny and so on.
    df_val_cnts = df['loc12'].value_counts()
    
    # We takes combinations only if they occur more then 100 times in dataset.
    loc12_vals = set(df_val_cnts[ df_val_cnts > 100].index.values)
    for item in loc12_vals:
        df[item] = df['loc12'] == item    

    # Floor
    floors_dict = {'parter': 0, '> 10': 11, 'poddasze': -2, 'suterena': -1}
    df['floor_num'] = df['floor'].map(lambda x: floors_dict.get(x, x)).fillna(-10).astype('int')
   
    # Czynsz (Rent)
    df['rent_num'] = df['czynsz'].map(parse_czynsz)
    
    # Floors_in_building
    df['floors_in_building_num'] = df['floors_in_building'].map(parse_floors_in_building)
  
    # Rok budowy (build_year)
    df['build_year'] = df['rok budowy'].fillna(-1).astype('int')
    df["build_year_norm"] = df["build_year"].map(build_year_norm)
    
    # OHE: materiał budynku, okna, stan wykończenia, rodzaj zabudowy, ogrzewanie, forma własności.
    cat_feats = {
        "materiał budynku": "build_material_cat",
        "okna": "window_cat",
        "stan wykończenia": "property_completion_cat",
        "rodzaj zabudowy": "property_type_cat",
        "ogrzewanie": "property_heating_cat",
        "forma własności": "own_property_cat"
     }    
    
    for feat_name, feat_new_name in cat_feats.items():
        df[feat_new_name] = df[feat_name].factorize()[0] 
        df_dummies = pd.get_dummies(df[feat_name])
        df_dummies.columns = ['{0}_{1}'.format(feat_new_name, x) for x in df_dummies.columns]
        df = pd.concat([df, df_dummies], axis=1)
        

    df['security'] = df['system alarmowy'] | df['rolety antywłamaniowe'] | df['drzwi / okna antywłamaniowe']


    # Price agreggations.
    groupby_city_price = df_groupby_feat(df, ['city'], 'price')        
    if 'median_city_price' not in df:
        df = pd.merge(df, groupby_city_price, on='city', how='left')
        
    groupby_county_price = df_groupby_feat(df, ['county'], 'price')        
    if 'median_county_price' not in df:
        df = pd.merge(df, groupby_county_price, on='county', how='left')
    
    
    # Primary_market
    df = concat_and_factorize(df, 'is_primary_market', 'rooms')
    df = concat_and_factorize(df, 'is_primary_market', 'city')
    df = concat_and_factorize(df, 'is_primary_market', 'rodzaj zabudowy')
    
    
    # Price for m2 aggregation(is_primaru_market).
    groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_rooms'], 'price_m2')
    if 'median_is_primary_market_rooms_price_m2' not in df:
        df = pd.merge(df, groupby_price_m2, on='is_primary_market_rooms', how='left')
 
    groupby_price_m2 = df_groupby_feat(df, ['is_primary_market_rodzaj zabudowy'], 'price_m2')
    if 'median_is_primary_market_rodzaj zabudowy_price_m2' not in df:
        df = pd.merge(df, groupby_price_m2, on='is_primary_market_rodzaj zabudowy', how='left')

        
    # Stats
    stats = df['stats'].apply(pd.Series)
    df = pd.concat([df, stats], axis=1)
    dict_created_at={
        'ponad 14 dni temu':18,  
        '23.10.2018':17,
        '24.10.2018':16,
        '25.10.2018':15,
        '26.10.2018':14, 
        '27.10.2018':13,
        '28.10.2018':12,
        '29.10.2018':11,
        '30.10.2018':10,
        '31.10.2018':9,
        '01.11.2018':8,    
        '02.11.2018':7,
        '03.11.2018':6,
        '04.11.2018':5,
        '05.11.2018':4,
        '06.11.2018':3,
        '07.11.2018':2,
        '08.11.2018':1,
    }
        
    df['created_at_cat'] = df['created_at'].map(dict_created_at)
    df['visit_ads_num'] = df.visit_ads.map(lambda x: np.log(int(x) + 10) if not isinstance(x, float)  else -1)
                                                                   
    return df

# %%
df_fe = feature_engineering(df_org.copy())
print(df_fe.shape)
df_fe.sample(3)
# Out:
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[item] = df['loc12'] == item
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:141: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['floor_num'] = df['floor'].map(lambda x: floors_dict.get(x, x)).fillna(-10).astype('int')
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:144: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['rent_num'] = df['czynsz'].map(parse_czynsz)
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:147: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['floors_in_building_num'] = df['floors_in_building'].map(parse_floors_in_building)
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:150: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['build_year'] = df['rok budowy'].fillna(-1).astype('int')
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:151: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["build_year_norm"] = df["build_year"].map(build_year_norm)
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[feat_new_name] = df[feat_name].factorize()[0]
# C:\Users\kowsc\AppData\Local\Temp/ipykernel_16024/4110877577.py:170: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['security'] = df['system alarmowy'] | df['rolety antywłamaniowe'] | df['drzwi / okna antywłamaniowe']
# (92764, 376)
#           id                                           location  is_private  \
# 13188  26292  [małopolskie, Kraków, Stare Miasto, ul. Starow...           0
# 11021  21979  [małopolskie, Kraków, Wincentego Weryhy-Darows...           0
# 31705  63211          [śląskie, Katowice, Wełnowiec, Bytkowska]           0
#
#        piekarnik  garaż  monitoring / ochrona  rolety antywłamaniowe  \
# 13188      False  False                 False                  False
# 11021      False  False                 False                  False
# 31705      False  False                 False                  False
#
#        kuchenka  taras  balkon  ogródek  dwupoziomowe  system alarmowy  \
# 13188     False  False   False    False         False            False
# 11021     False  False    True    False         False            False
# 31705     False  False    True    False         False            False
#
#        pom. użytkowe  klimatyzacja  tarasy  teren zamknięty  internet  winda  \
# 13188          False         False   False             True      True  False
# 11021          False         False   False             True      True  False
# 31705          False         False   False            False     False  False
#
#        telefon  pralka  piwnica  ochrona  telewizja kablowa  telewizor  \
# 13188    False   False    False    False               True      False
# 11021    False   False    False    False              False      False
# 31705    False   False    False    False              False      False
#
#        lodówka  domofon / wideofon  oddzielna kuchnia  zmywarka  \
# 13188    False                True              False     False
# 11021    False               False              False     False
# 31705    False               False              False     False
#
#        garaż/miejsce parkingowe  meble  drzwi / okna antywłamaniowe  \
# 13188                     False  False                        False
# 11021                     False  False                        False
# 31705                      True  False                        False
#
#        plan zagospodarowania:     price      area  rooms     floor  \
# 13188                   False  340000.0  28,40 m²      1  poddasze
# 11021                   False  420000.0     54 m²      2         2
# 31705                   False  347097.0  62,54 m²      2         2
#
#       floors_in_building           dostępne od rok budowy materiał budynku  \
# 13188              (z 2)  31 października 2018       2018            cegła
# 11021              (z 3)                   NaN       2010              NaN
# 31705              (z 4)                   NaN        NaN              NaN
#
#              okna data rozpoczęcia stan inwestycji liczba kondygnacji  \
# 13188   drewniane              NaN             NaN                NaN
# 11021  plastikowe              NaN             NaN                NaN
# 31705  plastikowe              NaN             NaN                NaN
#
#       stan wykończenia  czynsz  rodzaj zabudowy ogrzewanie forma własności  \
# 13188   do wykończenia     NaN        kamienica     gazowe  pełna własność
# 11021              NaN  210 zł             blok        NaN  pełna własność
# 31705              NaN     NaN  apartamentowiec        NaN  pełna własność
#
#                                                    stats  \
# 13188  {'ID': 112378192, 'created_at': 'ponad 14 dni ...
# 11021  {'ID': 112943816, 'visit_ads': '104', 'created...
# 31705  {'ID': 112691128, 'visit_ads': '67', 'created_...
#
#                                                     text  is_primary_market  \
# 13188  Opis Na sprzedaż mieszkanie 1-pokojowe o pow. ...              False
# 11021  Opis | 2 pok 54 m2 Weryhy Darowskiego/Bronowic...              False
# 31705  Opis Do sprzedaży nowe mieszkania  w zielonej ...              False
#
#        area_num  area_norm  area_num_log      price_m2  area_per_room  \
# 13188     28.40      28.40      3.346389  11971.830986          28.40
# 11021     54.00      54.00      3.988984   7777.777778          27.00
# 31705     62.54      62.54      4.135806   5550.000000          31.27
#
#           province      city  province_city       county  city_area  \
# 13188  małopolskie    Kraków           True    Kraków[a]     326.85
# 11021  małopolskie    Kraków           True    Kraków[a]     326.85
# 31705      śląskie  Katowice           True  Katowice[a]     164.64
#
#        city_population  city_density  province_population  \
# 13188         767348.0        2348.0              3372618
# 11021         767348.0        2348.0              3372618
# 31705         296262.0        1799.0              4570849
#
#        province_men_population  province_women_population         loc0  \
# 13188                  1636707                    1735911  małopolskie
# 11021                  1636707                    1735911  małopolskie
# 31705                  2204972                    2365877      śląskie
#
#            loc1                           loc2             loc3 loc4  \
# 13188    Kraków                   Stare Miasto  ul. Starowiślna
# 11021    Kraków  Wincentego Weryhy-Darowskiego
# 31705  Katowice                      Wełnowiec        Bytkowska
#
#                    loc01                                          loc012  \
# 13188  małopolskieKraków                   małopolskieKrakówStare Miasto
# 11021  małopolskieKraków  małopolskieKrakówWincentego Weryhy-Darowskiego
# 31705    śląskieKatowice                        śląskieKatowiceWełnowiec
#
#                                      loc12  loc0_cat  loc1_cat  loc2_cat  \
# 13188                   KrakówStare Miasto         5        95        26
# 11021  KrakówWincentego Weryhy-Darowskiego         5        95      1003
# 31705                    KatowiceWełnowiec        11       205      2341
#
#        loc3_cat  loc4_cat  loc01_cat  loc012_cat  loc12_cat  city_cat  \
# 13188      2498         0         97         933        933       162
# 11021         1         0         97        1083       1083       162
# 31705      5880         0        211        2611       2611       358
#
#        county_cat  province_cat  Wrocław  big_city  Kraków  Gdańsk  Gdynia  \
# 13188         100             5    False      True    True   False   False
# 11021         100             5    False      True    True   False   False
# 31705         210            11    False      True   False   False   False
#
#        Warszawa  Katowice  Sopot  Szczecin  Poznań  Olsztyn  Kalisz  Opole  \
# 13188     False     False  False     False   False    False   False  False
# 11021     False     False  False     False   False    False   False  False
# 31705     False      True  False     False   False    False   False  False
#
#        Częstochowa   Łódź  świdnickiŚwidnica  KrakówWola Justowska  \
# 13188        False  False              False                 False
# 11021        False  False              False                 False
# 31705        False  False              False                 False
#
#        KrakówGrzegórzki  głogowskiGłogów  SzczecinWarszewo  ToruńNa Skarpie  \
# 13188             False            False             False            False
# 11021             False            False             False            False
# 31705             False            False             False            False
#
#        RzeszówDrabinianka  Zielona Góra  GdyniaObłuże  WrocławTarnogaj  \
# 13188               False         False         False            False
# 11021               False         False         False            False
# 31705               False         False         False            False
#
#        Gliwice  Rzeszów  BydgoszczBielawy  PoznańBułgarska 59  \
# 13188    False    False             False               False
# 11021    False    False             False               False
# 31705    False    False             False               False
#
#        WrocławPlac Grunwaldzki  wołomińskiMarki  gdańskiPruszcz Gdański  \
# 13188                    False            False                   False
# 11021                    False            False                   False
# 31705                    False            False                   False
#
#        inowrocławskiInowrocław  wejherowskiWejherowo  piaseczyńskiJózefosław  \
# 13188                    False                 False                   False
# 11021                    False                 False                   False
# 31705                    False                 False                   False
#
#        KatowiceBrynów  WrocławStare Miasto  PoznańPodolany  WarszawaGocław  \
# 13188           False                False           False           False
# 11021           False                False           False           False
# 31705           False                False           False           False
#
#        WrocławKlecina  WarszawaTargówek  Grudziądz  WrocławGaj  \
# 13188           False             False      False       False
# 11021           False             False      False       False
# 31705           False             False      False       False
#
#        ostrowskiOstrów Wielkopolski  ŁódźŚródmieście  GdyniaŚródmieście  \
# 13188                         False            False              False
# 11021                         False            False              False
# 31705                         False            False              False
#
#        KrakówWzgórza Krzesławickie  PoznańStare Miasto  krakowskiSkawina  \
# 13188                        False               False             False
# 11021                        False               False             False
# 31705                        False               False             False
#
#        WrocławKrzyki  BiałystokWysoki Stoczek  ToruńMokre  PoznańGrunwald  \
# 13188          False                    False       False           False
# 11021          False                    False       False           False
# 31705          False                    False       False           False
#
#        BiałystokCentrum  GdańskJelitkowo  KrakówMistrzejowice  LublinFelin  \
# 13188             False            False                False        False
# 11021             False            False                False        False
# 31705             False            False                False        False
#
#        GdańskJasień  PoznańWilda  KatowiceKostuchna  WarszawaWilanów  \
# 13188         False        False              False            False
# 11021         False        False              False            False
# 31705         False        False              False            False
#
#        ŁódźGórna  KatowiceOsiedle Tysiąclecia  ŁódźBałuty  \
# 13188      False                        False       False
# 11021      False                        False       False
# 31705      False                        False       False
#
#        Dąbrowa GórniczaGołonóg  KrakówStare Podgórze  będzińskiSiewierz  \
# 13188                    False                 False              False
# 11021                    False                 False              False
# 31705                    False                 False              False
#
#        tczewskiTczew  BydgoszczBartodzieje  SzczecinCentrum  \
# 13188          False                 False            False
# 11021          False                 False            False
# 31705          False                 False            False
#
#        WarszawaPraga-Północ  LublinWęglinek  WarszawaOchota  wejherowskiRumia  \
# 13188                 False           False           False             False
# 11021                 False           False           False             False
# 31705                 False           False           False             False
#
#        WarszawaWola  KrakówŁobzów  ŁódźPolesie  tatrzańskiZakopane  \
# 13188         False         False        False               False
# 11021         False         False        False               False
# 31705         False         False        False               False
#
#        BydgoszczFordon  GdańskMorena  WrocławJagodno  BydgoszczBłonie  \
# 13188            False         False           False            False
# 11021            False         False           False            False
# 31705            False         False           False            False
#
#        GdańskŚródmieście  KatowiceWełnowiec  WrocławŚródmieście  \
# 13188              False              False               False
# 11021              False              False               False
# 31705              False               True               False
#
#        Gorzów WielkopolskiGórczyn  będzińskiBędzin  GdańskStare Miasto  \
# 13188                       False            False               False
# 11021                       False            False               False
# 31705                       False            False               False
#
#        GdańskChełm  WarszawaWłochy  GdańskPrzymorze  SopotDolny  LublinCzuby  \
# 13188        False           False            False       False        False
# 11021        False           False            False       False        False
# 31705        False           False            False       False        False
#
#        WarszawaMokotów  GdyniaWitomino  BydgoszczWyżyny  Kielce  \
# 13188            False           False            False   False
# 11021            False           False            False   False
# 31705            False           False            False   False
#
#        Wrocławul. Brzoskwiniowa  WarszawaBemowo  WarszawaUrsus  PoznańŁazarz  \
# 13188                     False           False          False         False
# 11021                     False           False          False         False
# 31705                     False           False          False         False
#
#        LublinWrotków  poznańskiSwarzędz  GdańskSiedlce  BiałystokBojary  \
# 13188          False              False          False            False
# 11021          False              False          False            False
# 31705          False              False          False            False
#
#        wrocławskiSiechnice  dzierżoniowskiDzierżoniów  SosnowiecCentrum  \
# 13188                False                      False             False
# 11021                False                      False             False
# 31705                False                      False             False
#
#        LublinCentrum  BydgoszczSzwederowo  GliwiceStare Gliwice  \
# 13188          False                False                 False
# 11021          False                False                 False
# 31705          False                False                 False
#
#        BiałystokAntoniuk  KrakówWola Duchacka  SzczecinŚródmieście  \
# 13188              False                False                False
# 11021              False                False                False
# 31705              False                False                False
#
#        GdańskZaspa  KrakówPodgórze  GdyniaRedłowo  PoznańJeżyce  SopotGórny  \
# 13188        False           False          False         False       False
# 11021        False           False          False         False       False
# 31705        False           False          False         False       False
#
#        WrocławStabłowice  lubińskiLubin  KrakówNowa Huta  BydgoszczGlinki  \
# 13188              False          False            False            False
# 11021              False          False            False            False
# 31705              False          False            False            False
#
#        WarszawaBiałołęka  BiałystokNowe Miasto  KatowiceŚródmieście  \
# 13188              False                 False                False
# 11021              False                 False                False
# 31705              False                 False                False
#
#        ToruńKoniuchy  GdańskKowale  wielickiWieliczka  WarszawaŚródmieście  \
# 13188          False         False              False                False
# 11021          False         False              False                False
# 31705          False         False              False                False
#
#        KatowiceDolina Trzech Stawów  ełckiEłk  LublinDziesiąta  \
# 13188                         False     False            False
# 11021                         False     False            False
# 31705                         False     False            False
#
#        poznańskiZalasewo  GdańskOliwa  KatowicePiotrowice  \
# 13188              False        False               False
# 11021              False        False               False
# 31705              False        False               False
#
#        KatowiceOsiedle Paderewskiego  GdańskŁostowice  LublinLSM  \
# 13188                          False            False      False
# 11021                          False            False      False
# 31705                          False            False      False
#
#        BydgoszczGórzyskowo  GdyniaOksywie  PoznańWilczak  WarszawaPowiśle  \
# 13188                False          False          False            False
# 11021                False          False          False            False
# 31705                False          False          False            False
#
#        pruszkowskiPruszków  KrakówCzyżyny  wołomińskiZąbki  BydgoszczCentrum  \
# 13188                False          False            False             False
# 11021                False          False            False             False
# 31705                False          False            False             False
#
#        CzęstochowaParkitka  ŁódźWidzew  WrocławFabryczna  KielceCentrum  \
# 13188                False       False             False          False
# 11021                False       False             False          False
# 31705                False       False             False          False
#
#        KrakówPrądnik Biały  PoznańNowe Miasto  WrocławSwojczyce  BytomCentrum  \
# 13188                False              False             False         False
# 11021                False              False             False         False
# 31705                False              False             False         False
#
#        SosnowiecPogoń  ToruńRubinkowo  WarszawaPraga-Południe  PoznańCentrum  \
# 13188           False           False                   False          False
# 11021           False           False                   False          False
# 31705           False           False                   False          False
#
#        kołobrzeskiKołobrzeg  ToruńBydgoskie Przedmieście  lęborskiLębork  \
# 13188                 False                        False           False
# 11021                 False                        False           False
# 31705                 False                        False           False
#
#        WarszawaBielany  ZabrzeCentrum  ToruńJakubskie Przedmieście  \
# 13188            False          False                        False
# 11021            False          False                        False
# 31705            False          False                        False
#
#        poznańskiLuboń  PoznańWinogrady  KrakówKazimierz  KrakówDębniki  \
# 13188           False            False            False          False
# 11021           False            False            False          False
# 31705           False            False            False          False
#
#        TychyŻwaków  piaseczyńskiPiaseczno  KrakówBieżanów-Prokocim  \
# 13188        False                  False                    False
# 11021        False                  False                    False
# 31705        False                  False                    False
#
#        GliwiceCentrum  GdyniaMały Kack  SzczecinNiebuszewo  \
# 13188           False            False               False
# 11021           False            False               False
# 31705           False            False               False
#
#        tarnogórskiTarnowskie Góry  KrakówPrądnik Czerwony  WarszawaSaska Kępa  \
# 13188                       False                   False               False
# 11021                       False                   False               False
# 31705                       False                   False               False
#
#        PoznańPiątkowo  OpoleŚródmieście  PoznańNaramowice  KielceŚlichowice  \
# 13188           False             False             False             False
# 11021           False             False             False             False
# 31705           False             False             False             False
#
#        puckiJastarnia  SzczecinPogodno  KrakówBronowice Małe  GdańskUjeścisko  \
# 13188           False            False                 False            False
# 11021           False            False                 False            False
# 31705           False            False                 False            False
#
#        KrakówSalwator  LublinŚródmieście  KatowiceJózefowiec  KrakówKrowodrza  \
# 13188           False              False               False            False
# 11021           False              False               False            False
# 31705           False              False               False            False
#
#        wejherowskiReda  KrakówOlsza  WrocławHuby  KrakówKliny-Zacisze  \
# 13188            False        False        False                False
# 11021            False        False        False                False
# 31705            False        False        False                False
#
#        SosnowiecZagórze  stargardzkiStargard  KrakówKurdwanów  \
# 13188             False                False            False
# 11021             False                False            False
# 31705             False                False            False
#
#        BydgoszczOsiedle Leśne  ToruńChełmińskie Przedmieście  \
# 13188                   False                          False
# 11021                   False                          False
# 31705                   False                          False
#
#        wrocławskiKiełczów  SzczecinGumieńce  WrocławZłotniki  RzeszówSłocina  \
# 13188               False             False            False           False
# 11021               False             False            False           False
# 31705               False             False            False           False
#
#        KrakówStare Miasto  KrakówRuczaj  KrakówBronowice  WarszawaUrsynów  \
# 13188                True         False            False            False
# 11021               False         False            False            False
# 31705               False         False            False            False
#
#        GdyniaOrłowo  KrakówŚródmieście  WarszawaWawer  BydgoszczŚródmieście  \
# 13188         False              False          False                 False
# 11021         False              False          False                 False
# 31705         False              False          False                 False
#
#        namysłowskiNamysłów  CzęstochowaTysiąclecie  BydgoszczKapuściska  \
# 13188                False                   False                False
# 11021                False                   False                False
# 31705                False                   False                False
#
#        WarszawaŻoliborz  WrocławMuchobór Wielki  Zielona GóraCentrum  \
# 13188             False                   False                False
# 11021             False                   False                False
# 31705             False                   False                False
#
#        LublinSzerokie  PoznańRataje  WrocławMaślice  kamieńskiMiędzyzdroje  \
# 13188           False         False           False                  False
# 11021           False         False           False                  False
# 31705           False         False           False                  False
#
#        PoznańGórczyn  WrocławPsie Pole  GdańskWrzeszcz  floor_num  rent_num  \
# 13188          False             False           False         -2       NaN
# 11021          False             False           False          2     210.0
# 31705          False             False           False          2       NaN
#
#        floors_in_building_num  build_year  build_year_norm  \
# 13188                     2.0        2018           2018.0
# 11021                     3.0        2010           2010.0
# 31705                     4.0          -1           1900.0
#
#        build_material_cat  build_material_cat_beton  \
# 13188                   1                         0
# 11021                  -1                         0
# 31705                  -1                         0
#
#        build_material_cat_beton komórkowy  build_material_cat_cegła  \
# 13188                                   0                         1
# 11021                                   0                         0
# 31705                                   0                         0
#
#        build_material_cat_drewno  build_material_cat_inne  \
# 13188                          0                        0
# 11021                          0                        0
# 31705                          0                        0
#
#        build_material_cat_keramzyt  build_material_cat_pustak  \
# 13188                            0                          0
# 11021                            0                          0
# 31705                            0                          0
#
#        build_material_cat_silikat  build_material_cat_wielka płyta  \
# 13188                           0                                0
# 11021                           0                                0
# 31705                           0                                0
#
#        build_material_cat_żelbet  window_cat  window_cat_aluminiowe  \
# 13188                          0           1                      0
# 11021                          0           0                      0
# 31705                          0           0                      0
#
#        window_cat_drewniane  window_cat_plastikowe  property_completion_cat  \
# 13188                     1                      0                        0
# 11021                     0                      1                       -1
# 31705                     0                      1                       -1
#
#        property_completion_cat_do remontu  \
# 13188                                   0
# 11021                                   0
# 31705                                   0
#
#        property_completion_cat_do wykończenia  \
# 13188                                       1
# 11021                                       0
# 31705                                       0
#
#        property_completion_cat_do zamieszkania  property_type_cat  \
# 13188                                        0                  2
# 11021                                        0                  1
# 31705                                        0                  4
#
#        property_type_cat_apartamentowiec  property_type_cat_blok  \
# 13188                                  0                       0
# 11021                                  0                       1
# 31705                                  1                       0
#
#        property_type_cat_dom wolnostojący  property_type_cat_kamienica  \
# 13188                                   0                            1
# 11021                                   0                            0
# 31705                                   0                            0
#
#        property_type_cat_loft  property_type_cat_plomba  \
# 13188                       0                         0
# 11021                       0                         0
# 31705                       0                         0
#
#        property_type_cat_szeregowiec  property_heating_cat  \
# 13188                              0                     0
# 11021                              0                    -1
# 31705                              0                    -1
#
#        property_heating_cat_elektryczne  property_heating_cat_gazowe  \
# 13188                                 0                            1
# 11021                                 0                            0
# 31705                                 0                            0
#
#        property_heating_cat_inne  property_heating_cat_kotłownia  \
# 13188                          0                               0
# 11021                          0                               0
# 31705                          0                               0
#
#        property_heating_cat_miejskie  property_heating_cat_piece kaflowe  \
# 13188                              0                                   0
# 11021                              0                                   0
# 31705                              0                                   0
#
#        own_property_cat  own_property_cat_pełna własność  \
# 13188                 0                                1
# 11021                 0                                1
# 31705                 0                                1
#
#        own_property_cat_spółdzielcze wł. z kw  \
# 13188                                       0
# 11021                                       0
# 31705                                       0
#
#        own_property_cat_spółdzielcze własnościowe  own_property_cat_udział  \
# 13188                                           0                        0
# 11021                                           0                        0
# 31705                                           0                        0
#
#        security  mean_city_price  median_city_price  mean_county_price  \
# 13188     False      529502.5000           416305.0        529502.5000
# 11021     False      529502.5000           416305.0        529502.5000
# 31705     False      327488.5625           289184.0        327488.5625
#
#        median_county_price is_primary_market_rooms  \
# 13188             416305.0                 False_1
# 11021             416305.0                 False_2
# 31705             289184.0                 False_2
#
#        is_primary_market_rooms_cat is_primary_market_city  \
# 13188                            7           False_Kraków
# 11021                            3           False_Kraków
# 31705                            3         False_Katowice
#
#        is_primary_market_city_cat is_primary_market_rodzaj zabudowy  \
# 13188                         222                   False_kamienica
# 11021                         222                        False_blok
# 31705                         523             False_apartamentowiec
#
#        is_primary_market_rodzaj zabudowy_cat  \
# 13188                                      5
# 11021                                      3
# 31705                                      9
#
#        mean_is_primary_market_rooms_price_m2  \
# 13188                            7201.175855
# 11021                            6437.640518
# 31705                            6437.640518
#
#        median_is_primary_market_rooms_price_m2  \
# 13188                              6666.666667
# 11021                              5813.953488
# 31705                              5813.953488
#
#        mean_is_primary_market_rodzaj zabudowy_price_m2  \
# 13188                                      6034.568709
# 11021                                      5587.835882
# 31705                                      9576.944357
#
#        median_is_primary_market_rodzaj zabudowy_price_m2         ID  \
# 13188                                        4906.693992  112378192
# 11021                                        5201.773009  112943816
# 31705                                        8492.838129  112691128
#
#               created_at         updated_at visit_ads  created_at_cat  \
# 13188  ponad 14 dni temu         24.10.2018       NaN              18
# 11021         02.11.2018         04.11.2018       104               7
# 31705  ponad 14 dni temu  ponad 14 dni temu        67              18
#
#        visit_ads_num
# 13188      -1.000000
# 11021       4.736198
# 31705       4.343805

# %% [markdown]
# # Dummy Model - Score: 182576.93612

# %%
feats = ['id']
model = DummyRegressor()
model.fit(df_train[feats].values, df_train['price'])
y_pred = model.predict(df_test[feats].values)

df_test['price'] = y_pred
df_test[ ['id', 'price'] ].to_csv('../output/DummyRegressor.csv', index=False)

# %%
#msno.bar(df_train.iloc[:,40:50])

# %% [markdown]
# ## MLflow

# %%
# !mlflow ui --backend-store-uri file:///mlruns
# Out:
# ^C

# %% [markdown]
# ## [MLflow Dashboard](http://localhost:5000)

# %% [markdown]
# ## Testing Models

# %%
start_experiment(df_fe,
                 'catboost_light', scoring=mean_absolute_error,
                 filename='catboost_light',
                 results=True,
                 export=True,
                 mlflow_save=True)
# Out:
# Working on "catboost_light_14" experiment.
# 5it [00:41,  8.22s/it]
# catboost_light_14.csv save successfully in "output" folder.
# Experiment catboost_light_14 recorded
# MAE SCORE: mean 62720.58822222085, std 1994.9434438704461
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2461
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1606
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0941
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0847
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0617
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0605
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num_log
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0408
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0395
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_is_primary_market_rodzaj zabudowy_price_m2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0204
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_primary_market
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0135
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_completion_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0123
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 visit_ads_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0101
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_is_primary_market_rodzaj zabudowy_price_m2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0095
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_heating_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0090
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 winda
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 loc2_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0066
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors_in_building_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0066
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 county_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_type_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0042
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em

# %%
start_experiment(df_fe, 'catboost_hyper', scoring=mean_absolute_error,
                 filename='catboost_hyper',
                 results=True,
                 export=True,
                 mlflow_save=True)
# Out:
# Working on "catboost_hyper_7" experiment.
# 5it [04:46, 57.34s/it]
# catboost_hyper_7.csv save successfully in "output" folder.
# Experiment catboost_hyper_7 recorded
# MAE SCORE: mean 52937.314563540844, std 2038.8693217414093
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1167
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1094
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_norm
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0806
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0713
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0568
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_city_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0443
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 build_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0360
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mean_county_price
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0257
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 visit_ads_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0254
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_num_log
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0206
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 median_is_primary_market_rodzaj zabudowy_price_m2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0203
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area_per_room
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0181
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_primary_market
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0177
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 property_type_cat_apartamentowiec
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0175
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 winda
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0172
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 loc2_cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0164
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_area
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0158
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 city_population
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0156
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0155
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floors_in_building_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0138
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
